# %%
import re

import orcaparse as op

# %% [markdown]
# `My data` and `Another data` blocks were recognized as `BlockUnrecognizedWithHeader` and `My start of the message messag` block was recognized as `BlockUnknown`

# %%
orca_file = op.File("example.out")
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.BlockUnrecognizedWithHeader'>`,returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.BlockUnrecognizedWithHeader'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:422: UserWarning: The block looks not structured. Please contribute to the project if you have knowledge on how to extract data from it.
#   warnings.warn(
#                  Type                      Subtype  \
# 7858779669156   Block  BlockFinalSinglePointEnergy
# 7858689244025   Block      BlockTerminatedNormally
# 7858689348092   Block            BlockTotalRunTime
# 7858689348086   Block  BlockUnrecognizedWithHeader
# 7858779679540   Block  BlockUnrecognizedWithHeader
# 7858689347789   Block                 BlockUnknown
# 7858689347909  Spacer                       Spacer
# 7858689347795  Spacer                       Spacer
# 7858689347990  Spacer                       Spacer
# 7858689348425  Spacer                       Spacer
#
#                                                          Element  Position  \
# 7858779669156  <orcaparse.elements.BlockFinalSinglePointEnerg...  (17, 19)
# 7858689244025  <orcaparse.elements.BlockTerminatedNormally ob...  (22, 22)
# 7858689348092  <orcaparse.elements.BlockTotalRunTime object a...  (23, 23)
# 7858689348086  <orcaparse.elements.BlockUnrecognizedWithHeade...   (5, 10)
# 7858779679540  <orcaparse.elements.BlockUnrecognizedWithHeade...  (11, 16)
# 7858689347789  <orcaparse.elements.BlockUnknown object at 0x7...    (2, 3)
# 7858689347909  <orcaparse.elements.Spacer object at 0x725be63...      None
# 7858689347795  <orcaparse.elements.Spacer object at 0x725be63...      None
# 7858689347990  <orcaparse.elements.Spacer object at 0x725be63...      None
# 7858689348425  <orcaparse.elements.Spacer object at 0x725be63...      None
#
#                                     ReadableName  \
# 7858779669156          FINAL SINGLE POINT ENERGY
# 7858689244025           ORCA TERMINATED NORMALLY
# 7858689348092                     TOTAL RUN TIME
# 7858689348086                            My data
# 7858779679540                       Another data
# 7858689347789  My start of the message messag...
# 7858689347909                               None
# 7858689347795                               None
# 7858689347990                               None
# 7858689348425                               None
#
#                                                          RawData  \
# 7858779669156  -------------------------   ------------------...
# 7858689244025                               ****ORCA TERMINAT...
# 7858689348092  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7858689348086  --------------------\nMy data\n---------------...
# 7858779679540                              ******************...
# 7858689347789        My start of the message: message1\nmessage2
# 7858689347909
# 7858689347795
# 7858689347990                                                 \n
# 7858689348425
#
#                       ExtractedData
# 7858779669156              [Energy]
# 7858689244025  [Termination status]
# 7858689348092            [Run Time]
# 7858689348086            [raw data]
# 7858779679540            [raw data]
# 7858689347789            [raw data]
# 7858689347909                  None
# 7858689347795                  None
# 7858689347990                  None
# 7858689348425                  None

# %% [markdown]
# Let's start with the simple ways of introducing your block, and later we will discuss the structure os the search and use the more advanced methods

# %%
rs = op.RegexSettings(op.DEFAULT_ORCA_REGEX_FILE)

# %% [markdown]
# `My data` and `Another data` blocks have quite a standard pattern: Single Line Header

# %% [markdown]
# Lets add `My data` to the blueprint for this type of patterns
# Use BlockNameOfBlock for the class name

# %%
rs.items["TypeKnownBlocks"].items[
    "BlueprintBlockWithSingeLineHeader"].add_item(name="BlockMyData",
                                                  pattern_text="My data")

# %% [markdown]
# We will detect the first block as paragraph that starts with 'My start of the message'

# %%
rs.items["TypeKnownBlocks"].items["BlueprintParagraphStartsWith"].add_item(
    name="BlockMyStart", pattern_text="My start of the message")

# %% [markdown]
# Let's look at the changes.
#
# We should load our new regex settings file at the creation of `File` object

# %%
orca_file = op.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/regex_request.py:197: UserWarning: Subtype `BlockMyStart` not recognized. Falling back to OrcaBlock.
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/regex_request.py:197: UserWarning: Subtype `BlockMyData` not recognized. Falling back to OrcaBlock.
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.Block'>`,returning the raw data:
# My start of the message: message1
# message2
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.Block'>`,returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.BlockUnrecognizedWithHeader'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#   warnings.warn(
#                  Type                      Subtype  \
# 7858689268577   Block                 BlockMyStart
# 7858779703281   Block                  BlockMyData
# 7858689268724   Block  BlockFinalSinglePointEnergy
# 7858779702600   Block      BlockTerminatedNormally
# 7858689335194   Block            BlockTotalRunTime
# 7858689268727   Block  BlockUnrecognizedWithHeader
# 7858689268634  Spacer                       Spacer
# 7858689268610  Spacer                       Spacer
# 7858779702510  Spacer                       Spacer
# 7858689184838  Spacer                       Spacer
#
#                                                          Element  Position  \
# 7858689268577  <orcaparse.elements.Block object at 0x725be61d...    (2, 3)
# 7858779703281  <orcaparse.elements.Block object at 0x725c3c5c...   (5, 10)
# 7858689268724  <orcaparse.elements.BlockFinalSinglePointEnerg...  (17, 19)
# 7858779702600  <orcaparse.elements.BlockTerminatedNormally ob...  (22, 22)
# 7858689335194  <orcaparse.elements.BlockTotalRunTime object a...  (23, 23)
# 7858689268727  <orcaparse.elements.BlockUnrecognizedWithHeade...  (11, 16)
# 7858689268634  <orcaparse.elements.Spacer object at 0x725be61...      None
# 7858689268610  <orcaparse.elements.Spacer object at 0x725be61...      None
# 7858779702510  <orcaparse.elements.Spacer object at 0x725c3c5...      None
# 7858689184838  <orcaparse.elements.Spacer object at 0x725be60...      None
#
#                                     ReadableName  \
# 7858689268577  My start of the message messag...
# 7858779703281               My data My value eV
# 7858689268724          FINAL SINGLE POINT ENERGY
# 7858779702600           ORCA TERMINATED NORMALLY
# 7858689335194                     TOTAL RUN TIME
# 7858689268727                       Another data
# 7858689268634                               None
# 7858689268610                               None
# 7858779702510                               None
# 7858689184838                               None
#
#                                                          RawData  \
# 7858689268577        My start of the message: message1\nmessage2
# 7858779703281  --------------------\nMy data\n---------------...
# 7858689268724  -------------------------   ------------------...
# 7858779702600                               ****ORCA TERMINAT...
# 7858689335194  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7858689268727                              ******************...
# 7858689268634
# 7858689268610
# 7858779702510                                                 \n
# 7858689184838
#
#                       ExtractedData
# 7858689268577            [raw data]
# 7858779703281            [raw data]
# 7858689268724              [Energy]
# 7858779702600  [Termination status]
# 7858689335194            [Run Time]
# 7858689268727            [raw data]
# 7858689268634                  None
# 7858689268610                  None
# 7858779702510                  None
# 7858689184838                  None

# %% [markdown]
# The Blocks were recognized as `BlockMyStart` and `BlockMyData`
#
# Now let's add the data recognition to `BlockMyData`
#
# Note that I am using `BlockWithStandardHeader` instead of just `Block`, as I know that this block has a standard header that can be easily separated. But I could use `Block`, then `ReadableName` would be recognized as 'My data My value eV'  instead of 'My data'
#
# Data extraction takes place only on a call, so you don't need to worry much about the performance of your code

# %%
@op.elements.AvailableBlocks.register_block
class BlockMyData(op.elements.BlockWithStandardHeader):

    def data(self):
        pattern = r"My value:\s*(\d+\.\d+)"
        match = re.search(pattern, self.raw_data)
        extracted_number = float(match.group(1)) if match else None
        value = extracted_number * op.units_and_constants.ureg.eV
        return op.Data(
            data={"My value": value, "Another Value": 42},
            comment="Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude\n`Another value` is 42.",
        )

# %% [markdown]
# Now lets add the `ReadableName` to `BlockMyStart`. Now it is 'My start of the message messag...'

# %%
@op.elements.AvailableBlocks.register_block
class BlockMyStart(op.elements.Block):

    def extract_name_header_and_body(self):
        return "My Start", None, self.raw_data

# %% [markdown]
# Do not forget to restart the orca file

# %%
orca_file = op.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class '__main__.BlockMyStart'>`,returning the raw data:
# My start of the message: message1
# message2
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:62: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.BlockUnrecognizedWithHeader'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#   warnings.warn(
#                  Type                      Subtype  \
# 7858689185282   Block                 BlockMyStart
# 7858689185084   Block                  BlockMyData
# 7858689185078   Block  BlockFinalSinglePointEnergy
# 7858689185072   Block      BlockTerminatedNormally
# 7858689185234   Block            BlockTotalRunTime
# 7858689184865   Block  BlockUnrecognizedWithHeader
# 7858689185294  Spacer                       Spacer
# 7858689185243  Spacer                       Spacer
# 7858689184925  Spacer                       Spacer
# 7858689185138  Spacer                       Spacer
#
#                                                          Element  Position  \
# 7858689185282   <__main__.BlockMyStart object at 0x725be6096020>    (2, 3)
# 7858689185084    <__main__.BlockMyData object at 0x725be60953c0>   (5, 10)
# 7858689185078  <orcaparse.elements.BlockFinalSinglePointEnerg...  (17, 19)
# 7858689185072  <orcaparse.elements.BlockTerminatedNormally ob...  (22, 22)
# 7858689185234  <orcaparse.elements.BlockTotalRunTime object a...  (23, 23)
# 7858689184865  <orcaparse.elements.BlockUnrecognizedWithHeade...  (11, 16)
# 7858689185294  <orcaparse.elements.Spacer object at 0x725be60...      None
# 7858689185243  <orcaparse.elements.Spacer object at 0x725be60...      None
# 7858689184925  <orcaparse.elements.Spacer object at 0x725be60...      None
# 7858689185138  <orcaparse.elements.Spacer object at 0x725be60...      None
#
#                             ReadableName  \
# 7858689185282                   My Start
# 7858689185084                    My data
# 7858689185078  FINAL SINGLE POINT ENERGY
# 7858689185072   ORCA TERMINATED NORMALLY
# 7858689185234             TOTAL RUN TIME
# 7858689184865               Another data
# 7858689185294                       None
# 7858689185243                       None
# 7858689184925                       None
# 7858689185138                       None
#
#                                                          RawData  \
# 7858689185282        My start of the message: message1\nmessage2
# 7858689185084  --------------------\nMy data\n---------------...
# 7858689185078  -------------------------   ------------------...
# 7858689185072                               ****ORCA TERMINAT...
# 7858689185234  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7858689184865                              ******************...
# 7858689185294
# 7858689185243
# 7858689184925                                                 \n
# 7858689185138
#
#                            ExtractedData
# 7858689185282                 [raw data]
# 7858689185084  [My value, Another Value]
# 7858689185078                   [Energy]
# 7858689185072       [Termination status]
# 7858689185234                 [Run Time]
# 7858689184865                 [raw data]
# 7858689185294                       None
# 7858689185243                       None
# 7858689184925                       None
# 7858689185138                       None

# %% [markdown]
# Now our data is ready to be extracted:

# %%
df = orca_file.get_data(element_type=BlockMyData)
assert len(df) == 1, "More then 1 `BlockMyData` found"
data = df.iloc[0].ExtractedData
print(data)
print()
print(f"{data['My value'].magnitude = }")
print(f"{data['Another Value'] = }")
# Out:
# OrcaData with items: `My value`, `Another Value`. Comment: Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude
# `Another value` is 42.
#
# data['My value'].magnitude = 1.234
# data['Another Value'] = 42

# %% [markdown]
# Let's looks at the search algorithm structure
#
# `RegexSettings` is a tree/'directory' object that contains  `RegexSettings`s, `RegexBlueprint`s and `RegexRequest`s. `RegexBlueprint` is a 'generator' object for `RegexRequest`s of the same type. They have `.items` that contains `RegexRequest`s as it was previously shown.

# %%
rs = op.RegexSettings(op.DEFAULT_ORCA_REGEX_FILE)
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockIcon: RegexRequest(p_type=Block, p_subtype=BlockIcon, pattern=^((?:[ \t]*#,[ \t]*\n[ \t..., flags=re.MULTILINE, comment=Searching for the fin of ...)
#       BlockShark: RegexRequest(p_type=Block, p_subtype=BlockShark, pattern=^(([ \t]*-{50,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Non-special line is defin...)
#       BlockWarnings: RegexRequest(p_type=Block, p_subtype=BlockWarnings, pattern=^(([ \t]*={10,}[ \t]*\n)[..., flags=re.MULTILINE, comment=Starts with ===, then WAR...)
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockVersion: Pattern: ^([ \t]*Program Version.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockRotationalSpectrum: Pattern: ^((?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:[ \t]*[-*#=]?[ \t]*Rotational spectrum[ \t]*[-*#=]?[ \t]*\n)(?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlockOrbitalBasis: RegexRequest(p_type=Block, p_subtype=BlockOrbitalBasis, pattern=^(([ \t]*-{3,} Orbital ba..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockAuxJBasis: RegexRequest(p_type=Block, p_subtype=BlockAuxJBasis, pattern=^(([ \t]*-{3,} AuxJ basis..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockInputFile: RegexRequest(p_type=Block, p_subtype=BlockInputFile, pattern=^(([ \t]*={10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Header then wait till ===...)
#       BlockAllRightsReserved: RegexRequest(p_type=Block, p_subtype=BlockAllRightsReserved, pattern=^([ \t]*#{40,}[ t]*\n([ \..., flags=re.MULTILINE|re.DOTALL, comment=)
#       PatternScf:
#         RegexGroup:
#           BlockScf: RegexRequest(p_type=Block, p_subtype=BlockScf, pattern=^(([ \t]*-{10,}S-C-F-{10,..., flags=re.MULTILINE, comment=Header then non-special n...)
#           BlockSoscf: RegexRequest(p_type=Block, p_subtype=BlockSoscf, pattern=^(([ \t]*-{10,}S-O-S-C-F-..., flags=re.MULTILINE, comment=Header then non-special n...)
#       BlockScfConverged: RegexRequest(p_type=Block, p_subtype=BlockScfConverged, pattern=^([ \t]*\*{40,}[ \t]*\n([..., flags=re.MULTILINE|re.DOTALL, comment=)
#       BlockFinalSinglePointEnergy: RegexRequest(p_type=Block, p_subtype=BlockFinalSinglePointEnergy, pattern=^(-{25}\s+-{20}\nFINAL SI..., flags=re.MULTILINE, comment=This pattern matches the ...)
#       BlockTerminatedNormally: RegexRequest(p_type=Block, p_subtype=BlockTerminatedNormally, pattern=^([ \t]*\*{4}ORCA TERMINA..., flags=re.MULTILINE, comment=)
#       BlockOrbitalEnergies: RegexRequest(p_type=Block, p_subtype=BlockOrbitalEnergies, pattern=^([ \t]*-{10,}[ \t]*\n[ \..., flags=re.MULTILINE, comment=)
#       BlockDipoleMoment: RegexRequest(p_type=Block, p_subtype=BlockDipoleMoment, pattern=^(([ \t]*-{10,}[ \t]*\n[ ..., flags=re.MULTILINE, comment=)
#       BlockTotalRunTime: RegexRequest(p_type=Block, p_subtype=BlockTotalRunTime, pattern=^([ \t]*TOTAL RUN TIME:\s..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockSuggestedCitations: RegexRequest(p_type=Block, p_subtype=BlockSuggestedCitations, pattern=^(([ \t]*-{10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Assumes that List of opti...)
#       BlockTimingsForIndividualModules: RegexRequest(p_type=Block, p_subtype=BlockTimingsForIndividualModules, pattern=^([ \t]*Timings for indiv..., flags=re.MULTILINE, comment=This pattern is intended ...)
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockUnrecognizedWithHeader_1: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockUnrecognizedWithHeader_2: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockUnrecognizedNotification: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedNotification, pattern=^(([ \t]*[-*#]{7,}[ \t]*)..., flags=re.MULTILINE, comment=What's left and looks lik...)
#       BlockUnrecognizedMessage: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedMessage, pattern=^([ \t]*[-*#=]+[ \t]*[^ \..., flags=re.MULTILINE, comment=What's left and looks lik...)
#   BlockUnknown: RegexRequest(p_type=Block, p_subtype=BlockUnknown, pattern=^((?:(?!^.*<@%.*%@>.*$|^[..., flags=re.MULTILINE, comment=I have no clue what that ...)
#   Spacer: RegexRequest(p_type=Spacer, p_subtype=Spacer, pattern=^(\s*)$, flags=re.MULTILINE, comment=Just some empty lines, ma...)

# %% [markdown]
# You can create the new instance of `RegexSettings`, `RegexBlueprint` or `RegexRequest` and add it with .add_item.
#
# `TypeKnownBlocks` is made for specific patterns for known blocks
#
# `TypeDefaultBlocks` is made for the general patters to find some specific kinds of blocks, data extraction is not expected from the blocks in this section
#
# `BlockUnknown` is the `RegexRequest` to collect everything that was not recognized before as a block and is not just a space
#
# `Spacer` collects the spaces left in the document

# %%
pattern = op.regex_request.RegexRequest(
    p_type="Block",
    p_subtype="BlockDemonstration",
    pattern="^(aaa)$",
    flags=["MULTILINE"],
    comment="Patterns should always start with ^, have at least 1 capturing group and end with $",
)
pattern
# Out:
# RegexRequest(p_type=Block, p_subtype=BlockDemonstration, pattern=^(aaa)$, flags=re.MULTILINE, comment=Patterns should always st...)

# %% [markdown]
# Patterns should always start with `^`, have at least 1 capturing group and end with `$`. This capturing group will capture the `raw_data`

# %%
rs.items["TypeKnownBlocks"].add_item(name="BlockDemonstration", item=pattern)

# %% [markdown]
# Pattern was successfully added:

# %%
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockIcon: RegexRequest(p_type=Block, p_subtype=BlockIcon, pattern=^((?:[ \t]*#,[ \t]*\n[ \t..., flags=re.MULTILINE, comment=Searching for the fin of ...)
#       BlockShark: RegexRequest(p_type=Block, p_subtype=BlockShark, pattern=^(([ \t]*-{50,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Non-special line is defin...)
#       BlockWarnings: RegexRequest(p_type=Block, p_subtype=BlockWarnings, pattern=^(([ \t]*={10,}[ \t]*\n)[..., flags=re.MULTILINE, comment=Starts with ===, then WAR...)
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockVersion: Pattern: ^([ \t]*Program Version.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockRotationalSpectrum: Pattern: ^((?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:[ \t]*[-*#=]?[ \t]*Rotational spectrum[ \t]*[-*#=]?[ \t]*\n)(?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlockOrbitalBasis: RegexRequest(p_type=Block, p_subtype=BlockOrbitalBasis, pattern=^(([ \t]*-{3,} Orbital ba..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockAuxJBasis: RegexRequest(p_type=Block, p_subtype=BlockAuxJBasis, pattern=^(([ \t]*-{3,} AuxJ basis..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockInputFile: RegexRequest(p_type=Block, p_subtype=BlockInputFile, pattern=^(([ \t]*={10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Header then wait till ===...)
#       BlockAllRightsReserved: RegexRequest(p_type=Block, p_subtype=BlockAllRightsReserved, pattern=^([ \t]*#{40,}[ t]*\n([ \..., flags=re.MULTILINE|re.DOTALL, comment=)
#       PatternScf:
#         RegexGroup:
#           BlockScf: RegexRequest(p_type=Block, p_subtype=BlockScf, pattern=^(([ \t]*-{10,}S-C-F-{10,..., flags=re.MULTILINE, comment=Header then non-special n...)
#           BlockSoscf: RegexRequest(p_type=Block, p_subtype=BlockSoscf, pattern=^(([ \t]*-{10,}S-O-S-C-F-..., flags=re.MULTILINE, comment=Header then non-special n...)
#       BlockScfConverged: RegexRequest(p_type=Block, p_subtype=BlockScfConverged, pattern=^([ \t]*\*{40,}[ \t]*\n([..., flags=re.MULTILINE|re.DOTALL, comment=)
#       BlockFinalSinglePointEnergy: RegexRequest(p_type=Block, p_subtype=BlockFinalSinglePointEnergy, pattern=^(-{25}\s+-{20}\nFINAL SI..., flags=re.MULTILINE, comment=This pattern matches the ...)
#       BlockTerminatedNormally: RegexRequest(p_type=Block, p_subtype=BlockTerminatedNormally, pattern=^([ \t]*\*{4}ORCA TERMINA..., flags=re.MULTILINE, comment=)
#       BlockOrbitalEnergies: RegexRequest(p_type=Block, p_subtype=BlockOrbitalEnergies, pattern=^([ \t]*-{10,}[ \t]*\n[ \..., flags=re.MULTILINE, comment=)
#       BlockDipoleMoment: RegexRequest(p_type=Block, p_subtype=BlockDipoleMoment, pattern=^(([ \t]*-{10,}[ \t]*\n[ ..., flags=re.MULTILINE, comment=)
#       BlockTotalRunTime: RegexRequest(p_type=Block, p_subtype=BlockTotalRunTime, pattern=^([ \t]*TOTAL RUN TIME:\s..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockSuggestedCitations: RegexRequest(p_type=Block, p_subtype=BlockSuggestedCitations, pattern=^(([ \t]*-{10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Assumes that List of opti...)
#       BlockTimingsForIndividualModules: RegexRequest(p_type=Block, p_subtype=BlockTimingsForIndividualModules, pattern=^([ \t]*Timings for indiv..., flags=re.MULTILINE, comment=This pattern is intended ...)
#       BlockDemonstration: RegexRequest(p_type=Block, p_subtype=BlockDemonstration, pattern=^(aaa)$, flags=re.MULTILINE, comment=Patterns should always st...)
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockUnrecognizedWithHeader_1: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockUnrecognizedWithHeader_2: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockUnrecognizedNotification: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedNotification, pattern=^(([ \t]*[-*#]{7,}[ \t]*)..., flags=re.MULTILINE, comment=What's left and looks lik...)
#       BlockUnrecognizedMessage: RegexRequest(p_type=Block, p_subtype=BlockUnrecognizedMessage, pattern=^([ \t]*[-*#=]+[ \t]*[^ \..., flags=re.MULTILINE, comment=What's left and looks lik...)
#   BlockUnknown: RegexRequest(p_type=Block, p_subtype=BlockUnknown, pattern=^((?:(?!^.*<@%.*%@>.*$|^[..., flags=re.MULTILINE, comment=I have no clue what that ...)
#   Spacer: RegexRequest(p_type=Spacer, p_subtype=Spacer, pattern=^(\s*)$, flags=re.MULTILINE, comment=Just some empty lines, ma...)
