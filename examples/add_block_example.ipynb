# %%
import re

import orcaparse as op

# %% [markdown]
# `My data` and `Another data` blocks were recognized as `BlockOrcaUnrecognizedWithHeader` and `My start of the message messag` block was recognized as `BlockOrcaUnknown`

# %%
orca_file = op.File("example.out")
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedWithHeader'>`,returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedMessage'>`,returning the raw data:
#                             *            Another data             *
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/orca_elements.py:106: UserWarning: The block looks not structured. Please contribute to the project if you have knowledge on how to extract data from it.
#   warnings.warn(
#                  Type                          Subtype  \
# 7954453380511   Block  BlockOrcaFinalSinglePointEnergy
# 7954453380577   Block      BlockOrcaTerminatedNormally
# 7954453380625   Block            BlockOrcaTotalRunTime
# 7954453380613   Block  BlockOrcaUnrecognizedWithHeader
# 7954453380529   Block     BlockOrcaUnrecognizedMessage
# 7954453380757   Block                 BlockOrcaUnknown
# 7954453380541   Block                 BlockOrcaUnknown
# 7954453380604  Spacer                           Spacer
# 7954453380664  Spacer                           Spacer
# 7954453380718  Spacer                           Spacer
# 7954453380565  Spacer                           Spacer
# 7954453380631  Spacer                           Spacer
# 7954453380403  Spacer                           Spacer
# 7954453380607  Spacer                           Spacer
# 7954453380697  Spacer                           Spacer
# 7954453380610  Spacer                           Spacer
# 7954453380763  Spacer                           Spacer
# 7954453380508  Spacer                           Spacer
# 7954453380967  Spacer                           Spacer
#
#                                                          Element CharPosition  \
# 7954453380511  <orcaparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7954453380577  <orcaparse.orca_elements.BlockOrcaTerminatedNo...   (503, 565)
# 7954453380625  <orcaparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7954453380613  <orcaparse.orca_elements.BlockOrcaUnrecognized...    (45, 184)
# 7954453380529  <orcaparse.orca_elements.BlockOrcaUnrecognized...   (185, 252)
# 7954453380757  <orcaparse.orca_elements.BlockOrcaUnknown obje...      (1, 43)
# 7954453380541  <orcaparse.orca_elements.BlockOrcaUnknown obje...   (253, 352)
# 7954453380604  <orcaparse.elements.Spacer object at 0x73c0a5e...       (0, 1)
# 7954453380664  <orcaparse.elements.Spacer object at 0x73c0a5e...       (1, 1)
# 7954453380718  <orcaparse.elements.Spacer object at 0x73c0a5e...     (43, 45)
# 7954453380565  <orcaparse.elements.Spacer object at 0x73c0a5e...     (45, 45)
# 7954453380631  <orcaparse.elements.Spacer object at 0x73c0a5e...   (184, 185)
# 7954453380403  <orcaparse.elements.Spacer object at 0x73c0a5e...   (185, 185)
# 7954453380607  <orcaparse.elements.Spacer object at 0x73c0a5e...   (252, 253)
# 7954453380697  <orcaparse.elements.Spacer object at 0x73c0a5e...   (253, 253)
# 7954453380610  <orcaparse.elements.Spacer object at 0x73c0a5e...   (352, 354)
# 7954453380763  <orcaparse.elements.Spacer object at 0x73c0a5e...   (354, 354)
# 7954453380508  <orcaparse.elements.Spacer object at 0x73c0a5e...   (500, 503)
# 7954453380967  <orcaparse.elements.Spacer object at 0x73c0a5e...   (503, 503)
#
#               LinePosition                       ReadableName  \
# 7954453380511     (17, 19)          FINAL SINGLE POINT ENERGY
# 7954453380577     (22, 23)           ORCA TERMINATED NORMALLY
# 7954453380625     (23, 23)                     TOTAL RUN TIME
# 7954453380613      (5, 11)                            My data
# 7954453380529     (12, 12)                      Another data
# 7954453380757       (2, 3)  My start of the message messag...
# 7954453380541     (13, 15)           Not my match My value eV
# 7954453380604       (1, 2)                               None
# 7954453380664       (2, 2)                               None
# 7954453380718       (3, 5)                               None
# 7954453380565       (5, 5)                               None
# 7954453380631     (11, 12)                               None
# 7954453380403     (12, 12)                               None
# 7954453380607     (12, 13)                               None
# 7954453380697     (13, 13)                               None
# 7954453380610     (15, 17)                               None
# 7954453380763     (17, 17)                               None
# 7954453380508     (19, 22)                               None
# 7954453380967     (22, 22)                               None
#
#                                                          RawData  \
# 7954453380511  -------------------------   ------------------...
# 7954453380577                               ****ORCA TERMINAT...
# 7954453380625  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7954453380613  --------------------\nMy data\n---------------...
# 7954453380529                              *            Anoth...
# 7954453380757        My start of the message: message1\nmessage2
# 7954453380541                              ******************...
# 7954453380604                                                 \n
# 7954453380664
# 7954453380718                                               \n\n
# 7954453380565
# 7954453380631                                                 \n
# 7954453380403
# 7954453380607                                                 \n
# 7954453380697
# 7954453380610                                               \n\n
# 7954453380763
# 7954453380508                                             \n\n\n
# 7954453380967
#
#                       ExtractedData
# 7954453380511              [Energy]
# 7954453380577  [Termination status]
# 7954453380625            [Run Time]
# 7954453380613            [raw data]
# 7954453380529            [raw data]
# 7954453380757            [raw data]
# 7954453380541            [raw data]
# 7954453380604                  None
# 7954453380664                  None
# 7954453380718                  None
# 7954453380565                  None
# 7954453380631                  None
# 7954453380403                  None
# 7954453380607                  None
# 7954453380697                  None
# 7954453380610                  None
# 7954453380763                  None
# 7954453380508                  None
# 7954453380967                  None

# %% [markdown]
# Let's start with the simple ways of introducing your block, and later we will discuss the structure os the search and use the more advanced methods

# %%
rs = op.RegexSettings(op.DEFAULT_ORCA_REGEX_FILE)

# %% [markdown]
# `My data` and `Another data` blocks have quite a standard pattern: Single Line Header

# %% [markdown]
# Lets add `My data` to the blueprint for this type of patterns
# Use BlockNameOfBlock for the class name

# %%
rs.items["TypeKnownBlocks"].items[
    "BlueprintBlockWithSingeLineHeader"].add_item(name="BlockOrcaMyData",
                                                  pattern_text="My data")

# %% [markdown]
# We will detect the first block as paragraph that starts with 'My start of the message'

# %%
rs.items["TypeKnownBlocks"].items["BlueprintParagraphStartsWith"].add_item(
    name="BlockOrcaMyStart", pattern_text="My start of the message")

# %% [markdown]
# Let's look at the changes.
#
# We should load our new regex settings file at the creation of `File` object

# %%
orca_file = op.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/regex_request.py:229: UserWarning: Subtype `BlockOrcaMyStart` not recognized. Falling back to Block.
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/regex_request.py:229: UserWarning: Subtype `BlockOrcaMyData` not recognized. Falling back to Block.
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.Block'>`,returning the raw data:
# My start of the message: message1
# message2
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.Block'>`,returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedNotification'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/orca_elements.py:106: UserWarning: The block looks not structured. Please contribute to the project if you have knowledge on how to extract data from it.
#   warnings.warn(
#                  Type                            Subtype  \
# 7954453381075   Block                   BlockOrcaMyStart
# 7954453380448   Block                    BlockOrcaMyData
# 7954453328921   Block    BlockOrcaFinalSinglePointEnergy
# 7954453328969   Block        BlockOrcaTerminatedNormally
# 7954453328975   Block              BlockOrcaTotalRunTime
# 7954453329026   Block  BlockOrcaUnrecognizedNotification
# 7954453329005   Block                   BlockOrcaUnknown
# 7954453329059  Spacer                             Spacer
# 7954453328906  Spacer                             Spacer
# 7954453329068  Spacer                             Spacer
# 7954453329077  Spacer                             Spacer
# 7954453329053  Spacer                             Spacer
# 7954453329047  Spacer                             Spacer
# 7954453328945  Spacer                             Spacer
# 7954453328984  Spacer                             Spacer
# 7954453329002  Spacer                             Spacer
# 7954453328987  Spacer                             Spacer
# 7954453329080  Spacer                             Spacer
# 7954453329140  Spacer                             Spacer
#
#                                                          Element CharPosition  \
# 7954453381075  <orcaparse.elements.Block object at 0x73c0a5e3...      (1, 43)
# 7954453380448  <orcaparse.elements.Block object at 0x73c0a5e3...    (45, 116)
# 7954453328921  <orcaparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7954453328969  <orcaparse.orca_elements.BlockOrcaTerminatedNo...   (503, 565)
# 7954453328975  <orcaparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7954453329026  <orcaparse.orca_elements.BlockOrcaUnrecognized...   (117, 320)
# 7954453329005  <orcaparse.orca_elements.BlockOrcaUnknown obje...   (321, 352)
# 7954453329059  <orcaparse.elements.Spacer object at 0x73c0a5d...       (0, 1)
# 7954453328906  <orcaparse.elements.Spacer object at 0x73c0a5d...       (1, 1)
# 7954453329068  <orcaparse.elements.Spacer object at 0x73c0a5d...     (43, 45)
# 7954453329077  <orcaparse.elements.Spacer object at 0x73c0a5d...     (45, 45)
# 7954453329053  <orcaparse.elements.Spacer object at 0x73c0a5d...   (116, 117)
# 7954453329047  <orcaparse.elements.Spacer object at 0x73c0a5d...   (117, 117)
# 7954453328945  <orcaparse.elements.Spacer object at 0x73c0a5d...   (320, 321)
# 7954453328984  <orcaparse.elements.Spacer object at 0x73c0a5d...   (321, 321)
# 7954453329002  <orcaparse.elements.Spacer object at 0x73c0a5d...   (352, 354)
# 7954453328987  <orcaparse.elements.Spacer object at 0x73c0a5d...   (354, 354)
# 7954453329080  <orcaparse.elements.Spacer object at 0x73c0a5d...   (500, 503)
# 7954453329140  <orcaparse.elements.Spacer object at 0x73c0a5d...   (503, 503)
#
#               LinePosition                       ReadableName  \
# 7954453381075       (2, 3)  My start of the message messag...
# 7954453380448      (5, 10)               My data My value eV
# 7954453328921     (17, 19)          FINAL SINGLE POINT ENERGY
# 7954453328969     (22, 23)           ORCA TERMINATED NORMALLY
# 7954453328975     (23, 23)                     TOTAL RUN TIME
# 7954453329026     (11, 13)                      Another data
# 7954453329005     (14, 15)           Not my match My value eV
# 7954453329059       (1, 2)                               None
# 7954453328906       (2, 2)                               None
# 7954453329068       (3, 5)                               None
# 7954453329077       (5, 5)                               None
# 7954453329053     (10, 11)                               None
# 7954453329047     (11, 11)                               None
# 7954453328945     (13, 14)                               None
# 7954453328984     (14, 14)                               None
# 7954453329002     (15, 17)                               None
# 7954453328987     (17, 17)                               None
# 7954453329080     (19, 22)                               None
# 7954453329140     (22, 22)                               None
#
#                                                          RawData  \
# 7954453381075        My start of the message: message1\nmessage2
# 7954453380448  --------------------\nMy data\n---------------...
# 7954453328921  -------------------------   ------------------...
# 7954453328969                               ****ORCA TERMINAT...
# 7954453328975  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7954453329026                              ******************...
# 7954453329005                   Not my match\nMy value: 9.876 eV
# 7954453329059                                                 \n
# 7954453328906
# 7954453329068                                               \n\n
# 7954453329077
# 7954453329053                                                 \n
# 7954453329047
# 7954453328945                                                 \n
# 7954453328984
# 7954453329002                                               \n\n
# 7954453328987
# 7954453329080                                             \n\n\n
# 7954453329140
#
#                       ExtractedData
# 7954453381075            [raw data]
# 7954453380448            [raw data]
# 7954453328921              [Energy]
# 7954453328969  [Termination status]
# 7954453328975            [Run Time]
# 7954453329026            [raw data]
# 7954453329005            [raw data]
# 7954453329059                  None
# 7954453328906                  None
# 7954453329068                  None
# 7954453329077                  None
# 7954453329053                  None
# 7954453329047                  None
# 7954453328945                  None
# 7954453328984                  None
# 7954453329002                  None
# 7954453328987                  None
# 7954453329080                  None
# 7954453329140                  None

# %% [markdown]
# The Blocks were recognized as `BlockOrcaMyStart` and `BlockOrcaMyData`
#
# Now let's add the data recognition to `BlockOrcaMyData`
#
# Note that I am using `BlockOrcaWithStandardHeader` instead of just `Block`, as I know that this block has a standard header that can be easily separated. But I could use `Block`, then `ReadableName` would be recognized as 'My data My value eV'  instead of 'My data'
#
# Data extraction takes place only on a call, so you don't need to worry much about the performance of your code

# %%
@op.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyData(op.orca_elements.BlockOrcaWithStandardHeader):

    def data(self):
        pattern = r"My value:\s*(\d+\.\d+)"
        match = re.search(pattern, self.raw_data)
        extracted_number = float(match.group(1)) if match else None
        value = extracted_number * op.units_and_constants.ureg.eV
        return op.Data(
            data={"My value": value, "Another Value": 42},
            comment="Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude\n`Another value` is 42.",
        )

# %% [markdown]
# Now lets add the `ReadableName` to `BlockOrcaMyStart`. Now it is 'My start of the message messag...'

# %%
@op.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyStart(op.elements.Block):

    def extract_name_header_and_body(self):
        return "My Start", None, self.raw_data

# %% [markdown]
# Do not forget to restart the orca file

# %%
orca_file = op.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class '__main__.BlockOrcaMyStart'>`,returning the raw data:
# My start of the message: message1
# message2
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedNotification'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/orca_elements.py:106: UserWarning: The block looks not structured. Please contribute to the project if you have knowledge on how to extract data from it.
#   warnings.warn(
#                  Type                            Subtype  \
# 7954453329500   Block                   BlockOrcaMyStart
# 7954453329488   Block                    BlockOrcaMyData
# 7954453329458   Block    BlockOrcaFinalSinglePointEnergy
# 7954453329518   Block        BlockOrcaTerminatedNormally
# 7954453329521   Block              BlockOrcaTotalRunTime
# 7954453329092   Block  BlockOrcaUnrecognizedNotification
# 7954453329455   Block                   BlockOrcaUnknown
# 7954453329344  Spacer                             Spacer
# 7954453329281  Spacer                             Spacer
# 7954453329332  Spacer                             Spacer
# 7954453329362  Spacer                             Spacer
# 7954453329452  Spacer                             Spacer
# 7954453329125  Spacer                             Spacer
# 7954453329164  Spacer                             Spacer
# 7954453329278  Spacer                             Spacer
# 7954453329413  Spacer                             Spacer
# 7954453329497  Spacer                             Spacer
# 7954453329356  Spacer                             Spacer
# 7954453329263  Spacer                             Spacer
#
#                                                          Element CharPosition  \
# 7954453329500  <__main__.BlockOrcaMyStart object at 0x73c0a5d...      (1, 43)
# 7954453329488  <__main__.BlockOrcaMyData object at 0x73c0a5d7...    (45, 116)
# 7954453329458  <orcaparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7954453329518  <orcaparse.orca_elements.BlockOrcaTerminatedNo...   (503, 565)
# 7954453329521  <orcaparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7954453329092  <orcaparse.orca_elements.BlockOrcaUnrecognized...   (117, 320)
# 7954453329455  <orcaparse.orca_elements.BlockOrcaUnknown obje...   (321, 352)
# 7954453329344  <orcaparse.elements.Spacer object at 0x73c0a5d...       (0, 1)
# 7954453329281  <orcaparse.elements.Spacer object at 0x73c0a5d...       (1, 1)
# 7954453329332  <orcaparse.elements.Spacer object at 0x73c0a5d...     (43, 45)
# 7954453329362  <orcaparse.elements.Spacer object at 0x73c0a5d...     (45, 45)
# 7954453329452  <orcaparse.elements.Spacer object at 0x73c0a5d...   (116, 117)
# 7954453329125  <orcaparse.elements.Spacer object at 0x73c0a5d...   (117, 117)
# 7954453329164  <orcaparse.elements.Spacer object at 0x73c0a5d...   (320, 321)
# 7954453329278  <orcaparse.elements.Spacer object at 0x73c0a5d...   (321, 321)
# 7954453329413  <orcaparse.elements.Spacer object at 0x73c0a5d...   (352, 354)
# 7954453329497  <orcaparse.elements.Spacer object at 0x73c0a5d...   (354, 354)
# 7954453329356  <orcaparse.elements.Spacer object at 0x73c0a5d...   (500, 503)
# 7954453329263  <orcaparse.elements.Spacer object at 0x73c0a5d...   (503, 503)
#
#               LinePosition               ReadableName  \
# 7954453329500       (2, 3)                   My Start
# 7954453329488      (5, 10)                    My data
# 7954453329458     (17, 19)  FINAL SINGLE POINT ENERGY
# 7954453329518     (22, 23)   ORCA TERMINATED NORMALLY
# 7954453329521     (23, 23)             TOTAL RUN TIME
# 7954453329092     (11, 13)              Another data
# 7954453329455     (14, 15)   Not my match My value eV
# 7954453329344       (1, 2)                       None
# 7954453329281       (2, 2)                       None
# 7954453329332       (3, 5)                       None
# 7954453329362       (5, 5)                       None
# 7954453329452     (10, 11)                       None
# 7954453329125     (11, 11)                       None
# 7954453329164     (13, 14)                       None
# 7954453329278     (14, 14)                       None
# 7954453329413     (15, 17)                       None
# 7954453329497     (17, 17)                       None
# 7954453329356     (19, 22)                       None
# 7954453329263     (22, 22)                       None
#
#                                                          RawData  \
# 7954453329500        My start of the message: message1\nmessage2
# 7954453329488  --------------------\nMy data\n---------------...
# 7954453329458  -------------------------   ------------------...
# 7954453329518                               ****ORCA TERMINAT...
# 7954453329521  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7954453329092                              ******************...
# 7954453329455                   Not my match\nMy value: 9.876 eV
# 7954453329344                                                 \n
# 7954453329281
# 7954453329332                                               \n\n
# 7954453329362
# 7954453329452                                                 \n
# 7954453329125
# 7954453329164                                                 \n
# 7954453329278
# 7954453329413                                               \n\n
# 7954453329497
# 7954453329356                                             \n\n\n
# 7954453329263
#
#                            ExtractedData
# 7954453329500                 [raw data]
# 7954453329488  [My value, Another Value]
# 7954453329458                   [Energy]
# 7954453329518       [Termination status]
# 7954453329521                 [Run Time]
# 7954453329092                 [raw data]
# 7954453329455                 [raw data]
# 7954453329344                       None
# 7954453329281                       None
# 7954453329332                       None
# 7954453329362                       None
# 7954453329452                       None
# 7954453329125                       None
# 7954453329164                       None
# 7954453329278                       None
# 7954453329413                       None
# 7954453329497                       None
# 7954453329356                       None
# 7954453329263                       None

# %% [markdown]
# Now our data is ready to be extracted:

# %%
df = orca_file.get_data(element_type=BlockOrcaMyData)
display(df)
assert len(df) == 1, "More then 1 `BlockOrcaMyData` found"
data = df.iloc[0].ExtractedData
print(data)
print()
print(f"{data['My value'].magnitude = }")
print(f"{data['Another Value'] = }")
# Out:
#                 Type          Subtype  \
# 7954453329488  Block  BlockOrcaMyData
#
#                                                          Element CharPosition  \
# 7954453329488  <__main__.BlockOrcaMyData object at 0x73c0a5d7...    (45, 116)
#
#               LinePosition ReadableName  \
# 7954453329488      (5, 10)      My data
#
#                                                          RawData  \
# 7954453329488  --------------------\nMy data\n---------------...
#
#                            ExtractedData
# 7954453329488  [My value, Another Value]
# OrcaData with items: `My value`, `Another Value`. Comment: Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude
# `Another value` is 42.
#
# data['My value'].magnitude = 1.234
# data['Another Value'] = 42

# %% [markdown]
# Let's looks at the search algorithm structure
#
# `RegexSettings` is a tree/'directory' object that contains  `RegexSettings`s, `RegexBlueprint`s and `RegexRequest`s. `RegexBlueprint` is a 'generator' object for `RegexRequest`s of the same type. They have `.items` that contains `RegexRequest`s as it was previously shown.

# %%
rs = op.RegexSettings(op.DEFAULT_ORCA_REGEX_FILE)
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaIcon: RegexRequest(p_type=Block, p_subtype=BlockOrcaIcon, pattern=^((?:[ \t]*#,[ \t]*\n[ \t..., flags=re.MULTILINE, comment=Searching for the fin of ...)
#       BlockOrcaShark: RegexRequest(p_type=Block, p_subtype=BlockOrcaShark, pattern=^(([ \t]*-{50,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Non-special line is defin...)
#       BlockOrcaWarnings: RegexRequest(p_type=Block, p_subtype=BlockOrcaWarnings, pattern=^(([ \t]*={10,}[ \t]*\n)[..., flags=re.MULTILINE, comment=Starts with ===, then WAR...)
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:[ \t]*[-*#=]?[ \t]*Rotational spectrum[ \t]*[-*#=]?[ \t]*\n)(?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlockOrcaOrbitalBasis: RegexRequest(p_type=Block, p_subtype=BlockOrcaOrbitalBasis, pattern=^(([ \t]*-{3,} Orbital ba..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockOrcaAuxJBasis: RegexRequest(p_type=Block, p_subtype=BlockOrcaAuxJBasis, pattern=^(([ \t]*-{3,} AuxJ basis..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockOrcaInputFile: RegexRequest(p_type=Block, p_subtype=BlockOrcaInputFile, pattern=^(([ \t]*={10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Header then wait till ===...)
#       BlockOrcaAllRightsReserved: RegexRequest(p_type=Block, p_subtype=BlockOrcaAllRightsReserved, pattern=^([ \t]*#{40,}[ t]*\n([ \..., flags=re.MULTILINE|re.DOTALL, comment=)
#       PatternScf:
#         RegexGroup:
#           BlockOrcaScf: RegexRequest(p_type=Block, p_subtype=BlockOrcaScf, pattern=^(([ \t]*-{10,}S-C-F-{10,..., flags=re.MULTILINE, comment=Header then non-special n...)
#           BlockOrcaSoscf: RegexRequest(p_type=Block, p_subtype=BlockOrcaSoscf, pattern=^(([ \t]*-{10,}S-O-S-C-F-..., flags=re.MULTILINE, comment=Header then non-special n...)
#       BlockOrcaScfConverged: RegexRequest(p_type=Block, p_subtype=BlockOrcaScfConverged, pattern=^([ \t]*\*{40,}[ \t]*\n([..., flags=re.MULTILINE|re.DOTALL, comment=)
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type=Block, p_subtype=BlockOrcaFinalSinglePointEnergy, pattern=^(-{25}\s+-{20}\nFINAL SI..., flags=re.MULTILINE, comment=This pattern matches the ...)
#       BlockOrcaTerminatedNormally: RegexRequest(p_type=Block, p_subtype=BlockOrcaTerminatedNormally, pattern=^([ \t]*\*{4}ORCA TERMINA..., flags=re.MULTILINE, comment=)
#       BlockOrcaOrbitalEnergies: RegexRequest(p_type=Block, p_subtype=BlockOrcaOrbitalEnergies, pattern=^([ \t]*-{10,}[ \t]*\n[ \..., flags=re.MULTILINE, comment=)
#       BlockOrcaDipoleMoment: RegexRequest(p_type=Block, p_subtype=BlockOrcaDipoleMoment, pattern=^(([ \t]*-{10,}[ \t]*\n[ ..., flags=re.MULTILINE, comment=)
#       BlockOrcaTotalRunTime: RegexRequest(p_type=Block, p_subtype=BlockOrcaTotalRunTime, pattern=^([ \t]*TOTAL RUN TIME:\s..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockOrcaSuggestedCitations: RegexRequest(p_type=Block, p_subtype=BlockOrcaSuggestedCitations, pattern=^(([ \t]*-{10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Assumes that List of opti...)
#       BlockOrcaTimingsForIndividualModules: RegexRequest(p_type=Block, p_subtype=BlockOrcaTimingsForIndividualModules, pattern=^([ \t]*Timings for indiv..., flags=re.MULTILINE, comment=This pattern is intended ...)
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithHeader_1: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockOrcaUnrecognizedWithHeader_2: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockOrcaUnrecognizedNotification: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedNotification, pattern=^(([ \t]*[-*#]{7,}[ \t]*)..., flags=re.MULTILINE, comment=What's left and looks lik...)
#       BlockOrcaUnrecognizedMessage: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedMessage, pattern=^([ \t]*[-*#=]+[ \t]*[^ \..., flags=re.MULTILINE, comment=What's left and looks lik...)
#   BlockOrcaUnknown: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnknown, pattern=^((?:(?!^.*<@%.*%@>.*$|^[..., flags=re.MULTILINE, comment=I have no clue what that ...)
#   Spacer: RegexRequest(p_type=Spacer, p_subtype=Spacer, pattern=^(\s*)$, flags=re.MULTILINE, comment=Just some empty lines, ma...)

# %% [markdown]
# You can create the new instance of `RegexSettings`, `RegexBlueprint` or `RegexRequest` and add it with .add_item.
#
# `TypeKnownBlocks` is made for specific patterns for known blocks
#
# `TypeDefaultBlocks` is made for the general patters to find some specific kinds of blocks, data extraction is not expected from the blocks in this section
#
# `BlockOrcaUnknown` is the `RegexRequest` to collect everything that was not recognized before as a block and is not just a space
#
# `Spacer` collects the spaces left in the document

# %%
pattern = op.regex_request.RegexRequest(
    p_type="Block",
    p_subtype="BlockOrcaDemonstration",
    pattern="^(aaa)$",
    flags=["MULTILINE"],
    comment="Patterns should always start with ^, have at least 1 capturing group and end with $",
)
pattern
# Out:
# RegexRequest(p_type=Block, p_subtype=BlockOrcaDemonstration, pattern=^(aaa)$, flags=re.MULTILINE, comment=Patterns should always st...)

# %% [markdown]
# Patterns should always start with `^`, have at least 1 capturing group and end with `$`. This capturing group will capture the `raw_data`

# %%
rs.items["TypeKnownBlocks"].add_item(name="BlockOrcaDemonstration", item=pattern)

# %% [markdown]
# Pattern was successfully added:

# %%
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaIcon: RegexRequest(p_type=Block, p_subtype=BlockOrcaIcon, pattern=^((?:[ \t]*#,[ \t]*\n[ \t..., flags=re.MULTILINE, comment=Searching for the fin of ...)
#       BlockOrcaShark: RegexRequest(p_type=Block, p_subtype=BlockOrcaShark, pattern=^(([ \t]*-{50,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Non-special line is defin...)
#       BlockOrcaWarnings: RegexRequest(p_type=Block, p_subtype=BlockOrcaWarnings, pattern=^(([ \t]*={10,}[ \t]*\n)[..., flags=re.MULTILINE, comment=Starts with ===, then WAR...)
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:[ \t]*[-*#=]?[ \t]*Rotational spectrum[ \t]*[-*#=]?[ \t]*\n)(?:[ \t]*[-*#=]{7,}[ \t]*\n)(?:(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*(?:\n(?=(?!^.*<@%.*%@>.*$|^[ \t]*[-*#=]{7,}[ \t]*$).*))?)*)
#       BlockOrcaOrbitalBasis: RegexRequest(p_type=Block, p_subtype=BlockOrcaOrbitalBasis, pattern=^(([ \t]*-{3,} Orbital ba..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockOrcaAuxJBasis: RegexRequest(p_type=Block, p_subtype=BlockOrcaAuxJBasis, pattern=^(([ \t]*-{3,} AuxJ basis..., flags=re.MULTILINE, comment=Starts with Orbital basis...)
#       BlockOrcaInputFile: RegexRequest(p_type=Block, p_subtype=BlockOrcaInputFile, pattern=^(([ \t]*={10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Header then wait till ===...)
#       BlockOrcaAllRightsReserved: RegexRequest(p_type=Block, p_subtype=BlockOrcaAllRightsReserved, pattern=^([ \t]*#{40,}[ t]*\n([ \..., flags=re.MULTILINE|re.DOTALL, comment=)
#       PatternScf:
#         RegexGroup:
#           BlockOrcaScf: RegexRequest(p_type=Block, p_subtype=BlockOrcaScf, pattern=^(([ \t]*-{10,}S-C-F-{10,..., flags=re.MULTILINE, comment=Header then non-special n...)
#           BlockOrcaSoscf: RegexRequest(p_type=Block, p_subtype=BlockOrcaSoscf, pattern=^(([ \t]*-{10,}S-O-S-C-F-..., flags=re.MULTILINE, comment=Header then non-special n...)
#       BlockOrcaScfConverged: RegexRequest(p_type=Block, p_subtype=BlockOrcaScfConverged, pattern=^([ \t]*\*{40,}[ \t]*\n([..., flags=re.MULTILINE|re.DOTALL, comment=)
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type=Block, p_subtype=BlockOrcaFinalSinglePointEnergy, pattern=^(-{25}\s+-{20}\nFINAL SI..., flags=re.MULTILINE, comment=This pattern matches the ...)
#       BlockOrcaTerminatedNormally: RegexRequest(p_type=Block, p_subtype=BlockOrcaTerminatedNormally, pattern=^([ \t]*\*{4}ORCA TERMINA..., flags=re.MULTILINE, comment=)
#       BlockOrcaOrbitalEnergies: RegexRequest(p_type=Block, p_subtype=BlockOrcaOrbitalEnergies, pattern=^([ \t]*-{10,}[ \t]*\n[ \..., flags=re.MULTILINE, comment=)
#       BlockOrcaDipoleMoment: RegexRequest(p_type=Block, p_subtype=BlockOrcaDipoleMoment, pattern=^(([ \t]*-{10,}[ \t]*\n[ ..., flags=re.MULTILINE, comment=)
#       BlockOrcaTotalRunTime: RegexRequest(p_type=Block, p_subtype=BlockOrcaTotalRunTime, pattern=^([ \t]*TOTAL RUN TIME:\s..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockOrcaSuggestedCitations: RegexRequest(p_type=Block, p_subtype=BlockOrcaSuggestedCitations, pattern=^(([ \t]*-{10,}[ \t]*\n)(..., flags=re.MULTILINE, comment=Assumes that List of opti...)
#       BlockOrcaTimingsForIndividualModules: RegexRequest(p_type=Block, p_subtype=BlockOrcaTimingsForIndividualModules, pattern=^([ \t]*Timings for indiv..., flags=re.MULTILINE, comment=This pattern is intended ...)
#       BlockOrcaDemonstration: RegexRequest(p_type=Block, p_subtype=BlockOrcaDemonstration, pattern=^(aaa)$, flags=re.MULTILINE, comment=Patterns should always st...)
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithHeader_1: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockOrcaUnrecognizedWithHeader_2: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedWithHeader, pattern=^(([ \t]*[-*#]{7,}[ \t]*\..., flags=re.MULTILINE, comment=This pattern stands for -...)
#       BlockOrcaUnrecognizedNotification: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedNotification, pattern=^(([ \t]*[-*#]{7,}[ \t]*)..., flags=re.MULTILINE, comment=What's left and looks lik...)
#       BlockOrcaUnrecognizedMessage: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedMessage, pattern=^([ \t]*[-*#=]+[ \t]*[^ \..., flags=re.MULTILINE, comment=What's left and looks lik...)
#   BlockOrcaUnknown: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnknown, pattern=^((?:(?!^.*<@%.*%@>.*$|^[..., flags=re.MULTILINE, comment=I have no clue what that ...)
#   Spacer: RegexRequest(p_type=Spacer, p_subtype=Spacer, pattern=^(\s*)$, flags=re.MULTILINE, comment=Just some empty lines, ma...)
