# %%
import re

import chemparse as chp

# %% [markdown]
# `My data` and `Another data` blocks were recognized as `BlockOrcaUnrecognizedWithHeader` and `My start of the message messag` block was recognized as `BlockUnknown`

# %%
orca_file = chp.File("example.out")
orca_file.get_data()
# Out:
# 2024-04-04 17:26:38,040 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#
# 2024-04-04 17:26:38,041 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#
# 2024-04-04 17:26:38,041 - chemparse - WARNING - The block looks unstructured. Please contribute to the project if you have knowledge on how to extract data from it.
#                  Type                                   Subtype  \
# 8698671792876   Block                     BlockOrcaTotalRunTime
# 8698671793023   Block               BlockOrcaTerminatedNormally
# 8698671792984   Block           BlockOrcaFinalSinglePointEnergy
# 8698671793098   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 8698671793092   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 8698671793080  Spacer                                    Spacer
# 8698671793122  Spacer                                    Spacer
# 8698671793110  Spacer                                    Spacer
# 8698671792816   Block                              BlockUnknown
#
#                                                          Element CharPosition  \
# 8698671792876  <chemparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 8698671793023  <chemparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 8698671792984  <chemparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 8698671793098  <chemparse.orca_elements.BlockOrcaUnrecognized...    (45, 116)
# 8698671793092  <chemparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 8698671793080  <chemparse.elements.Spacer object at 0x7e9513e...       (0, 0)
# 8698671793122  <chemparse.elements.Spacer object at 0x7e9513e...     (44, 44)
# 8698671793110  <chemparse.elements.Spacer object at 0x7e9513e...   (501, 502)
# 8698671792816  <chemparse.elements.BlockUnknown object at 0x7...      (1, 43)
#
#               LinePosition                       ReadableName  \
# 8698671792876     (24, 25)                     TOTAL RUN TIME
# 8698671793023     (23, 24)           ORCA TERMINATED NORMALLY
# 8698671792984     (18, 21)          FINAL SINGLE POINT ENERGY
# 8698671793098      (6, 12)                            My data
# 8698671793092     (13, 19)                       Another data
# 8698671793080       (1, 2)                               None
# 8698671793122       (6, 7)                               None
# 8698671793110     (22, 24)                               None
# 8698671792816       (3, 5)  My start of the message messag...
#
#                                                          RawData  \
# 8698671792876  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 8698671793023                               ****ORCA TERMINAT...
# 8698671792984  -------------------------   ------------------...
# 8698671793098  --------------------\nMy data\n---------------...
# 8698671793092                              ******************...
# 8698671793080                                                 \n
# 8698671793122                                                 \n
# 8698671793110                                               \n\n
# 8698671792816      My start of the message: message1\nmessage2\n
#
#                       ExtractedData
# 8698671792876            [Run Time]
# 8698671793023  [Termination status]
# 8698671792984              [Energy]
# 8698671793098            [raw data]
# 8698671793092            [raw data]
# 8698671793080                  None
# 8698671793122                  None
# 8698671793110                  None
# 8698671792816            [raw data]

# %% [markdown]
# Let's start with the simple ways of introducing your block, and later we will discuss the structure os the search and use the more advanced methods

# %%
rs = chp.RegexSettings(chp.DEFAULT_ORCA_REGEX_FILE)

# %% [markdown]
# `My data` and `Another data` blocks have quite a standard pattern: Single Line Header

# %% [markdown]
# Lets add `My data` to the blueprint for this type of patterns
# Use BlockNameOfBlock for the class name

# %%
rs.items["TypeKnownBlocks"].items[
    "BlueprintBlockWithSingeLineHeader"].add_item(name="BlockOrcaMyData",
                                                  pattern_text="My data")

# %% [markdown]
# We will detect the first block as paragraph that starts with 'My start of the message'

# %%
rs.items["TypeKnownBlocks"].items["BlueprintParagraphStartsWith"].add_item(
    name="BlockOrcaMyStart", pattern_text="My start of the message")

# %% [markdown]
# Let's look at the changes.
#
# We should load our new regex settings file at the creation of `File` object

# %%
orca_file = chp.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# 2024-04-04 17:26:38,077 - chemparse - WARNING - Subtype `BlockOrcaMyStart` not recognized. Falling back to Block.
# 2024-04-04 17:26:38,083 - chemparse - WARNING - Subtype `BlockOrcaMyData` not recognized. Falling back to Block.
# 2024-04-04 17:26:38,096 - chemparse - WARNING - No procedure for analyzing the data found in type `Block`, returning the raw data:
# My start of the message: message1
# message2
#
# 2024-04-04 17:26:38,096 - chemparse - WARNING - No procedure for analyzing the data found in type `Block`, returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#
# 2024-04-04 17:26:38,097 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#                  Type                                   Subtype  \
# 8698671798639   Block                     BlockOrcaTotalRunTime
# 8698671798612   Block               BlockOrcaTerminatedNormally
# 8698671798681   Block           BlockOrcaFinalSinglePointEnergy
# 8698671798630   Block                          BlockOrcaMyStart
# 8698671798798   Block                           BlockOrcaMyData
# 8698671798816   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 8698671798774  Spacer                                    Spacer
# 8698671798618  Spacer                                    Spacer
# 8698671798741  Spacer                                    Spacer
#
#                                                          Element CharPosition  \
# 8698671798639  <chemparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 8698671798612  <chemparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 8698671798681  <chemparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 8698671798630  <chemparse.elements.Block object at 0x7e9513e1...      (1, 43)
# 8698671798798  <chemparse.elements.Block object at 0x7e9513e1...    (45, 116)
# 8698671798816  <chemparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 8698671798774  <chemparse.elements.Spacer object at 0x7e9513e...       (0, 0)
# 8698671798618  <chemparse.elements.Spacer object at 0x7e9513e...     (44, 44)
# 8698671798741  <chemparse.elements.Spacer object at 0x7e9513e...   (501, 502)
#
#               LinePosition                       ReadableName  \
# 8698671798639     (24, 25)                     TOTAL RUN TIME
# 8698671798612     (23, 24)           ORCA TERMINATED NORMALLY
# 8698671798681     (18, 21)          FINAL SINGLE POINT ENERGY
# 8698671798630       (3, 5)  My start of the message messag...
# 8698671798798      (8, 14)               My data My value eV
# 8698671798816     (15, 21)                       Another data
# 8698671798774       (1, 2)                               None
# 8698671798618       (6, 7)                               None
# 8698671798741     (22, 24)                               None
#
#                                                          RawData  \
# 8698671798639  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 8698671798612                               ****ORCA TERMINAT...
# 8698671798681  -------------------------   ------------------...
# 8698671798630      My start of the message: message1\nmessage2\n
# 8698671798798  --------------------\nMy data\n---------------...
# 8698671798816                              ******************...
# 8698671798774                                                 \n
# 8698671798618                                                 \n
# 8698671798741                                               \n\n
#
#                       ExtractedData
# 8698671798639            [Run Time]
# 8698671798612  [Termination status]
# 8698671798681              [Energy]
# 8698671798630            [raw data]
# 8698671798798            [raw data]
# 8698671798816            [raw data]
# 8698671798774                  None
# 8698671798618                  None
# 8698671798741                  None

# %% [markdown]
# The Blocks were recognized as `BlockOrcaMyStart` and `BlockOrcaMyData`
#
# Now let's add the data recognition to `BlockOrcaMyData`
#
# Note that I am using `BlockOrcaWithStandardHeader` instead of just `Block`, as I know that this block has a standard header that can be easily separated. But I could use `Block`, then `ReadableName` would be recognized as 'My data My value eV'  instead of 'My data'
#
# Data extraction takes place only on a call, so you don't need to worry much about the performance of your code

# %%
@chp.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyData(chp.orca_elements.BlockOrcaWithStandardHeader):

    def data(self):
        pattern = r"My value:\s*(\d+\.\d+)"
        match = re.search(pattern, self.raw_data)
        extracted_number = float(match.group(1)) if match else None
        value = extracted_number * chp.units_and_constants.ureg.eV
        return chp.Data(
            data={"My value": value, "Another Value": 42},
            comment="Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude\n`Another value` is 42.",
        )

# %% [markdown]
# Now lets add the `ReadableName` to `BlockOrcaMyStart`. Now it is 'My start of the message messag...'

# %%
@chp.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyStart(chp.elements.Block):

    def extract_name_header_and_body(self):
        return "My Start", None, self.raw_data

# %% [markdown]
# Do not forget to restart the orca file

# %%
orca_file = chp.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# 2024-04-04 17:26:38,143 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaMyStart`, returning the raw data:
# My start of the message: message1
# message2
#
# 2024-04-04 17:26:38,144 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#                  Type                                   Subtype  \
# 8698671798885   Block                     BlockOrcaTotalRunTime
# 8698671798888   Block               BlockOrcaTerminatedNormally
# 8698671798654   Block           BlockOrcaFinalSinglePointEnergy
# 8698671799281   Block                          BlockOrcaMyStart
# 8698671799005   Block                           BlockOrcaMyData
# 8698671799062   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 8698671798600  Spacer                                    Spacer
# 8698671799215  Spacer                                    Spacer
# 8698671798651  Spacer                                    Spacer
#
#                                                          Element CharPosition  \
# 8698671798885  <chemparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 8698671798888  <chemparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 8698671798654  <chemparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 8698671799281  <__main__.BlockOrcaMyStart object at 0x7e9513e...      (1, 43)
# 8698671799005  <__main__.BlockOrcaMyData object at 0x7e9513e1...    (45, 116)
# 8698671799062  <chemparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 8698671798600  <chemparse.elements.Spacer object at 0x7e9513e...       (0, 0)
# 8698671799215  <chemparse.elements.Spacer object at 0x7e9513e...     (44, 44)
# 8698671798651  <chemparse.elements.Spacer object at 0x7e9513e...   (501, 502)
#
#               LinePosition               ReadableName  \
# 8698671798885     (24, 25)             TOTAL RUN TIME
# 8698671798888     (23, 24)   ORCA TERMINATED NORMALLY
# 8698671798654     (18, 21)  FINAL SINGLE POINT ENERGY
# 8698671799281       (3, 5)                   My Start
# 8698671799005      (8, 14)                    My data
# 8698671799062     (15, 21)               Another data
# 8698671798600       (1, 2)                       None
# 8698671799215       (6, 7)                       None
# 8698671798651     (22, 24)                       None
#
#                                                          RawData  \
# 8698671798885  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 8698671798888                               ****ORCA TERMINAT...
# 8698671798654  -------------------------   ------------------...
# 8698671799281      My start of the message: message1\nmessage2\n
# 8698671799005  --------------------\nMy data\n---------------...
# 8698671799062                              ******************...
# 8698671798600                                                 \n
# 8698671799215                                                 \n
# 8698671798651                                               \n\n
#
#                            ExtractedData
# 8698671798885                 [Run Time]
# 8698671798888       [Termination status]
# 8698671798654                   [Energy]
# 8698671799281                 [raw data]
# 8698671799005  [My value, Another Value]
# 8698671799062                 [raw data]
# 8698671798600                       None
# 8698671799215                       None
# 8698671798651                       None

# %% [markdown]
# Now our data is ready to be extracted:

# %%
df = orca_file.get_data(element_type=BlockOrcaMyData)
display(df)
assert len(df) == 1, "More then 1 `BlockOrcaMyData` found"
data = df.iloc[0].ExtractedData
print(data)
print()
print(f"{data['My value'].magnitude = }")
print(f"{data['Another Value'] = }")
# Out:
#                 Type          Subtype  \
# 8698671799005  Block  BlockOrcaMyData
#
#                                                          Element CharPosition  \
# 8698671799005  <__main__.BlockOrcaMyData object at 0x7e9513e1...    (45, 116)
#
#               LinePosition ReadableName  \
# 8698671799005      (8, 14)      My data
#
#                                                          RawData  \
# 8698671799005  --------------------\nMy data\n---------------...
#
#                            ExtractedData
# 8698671799005  [My value, Another Value]
# Data with items: `My value`, `Another Value`. Comment: Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude
# `Another value` is 42.
#
# data['My value'].magnitude = 1.234
# data['Another Value'] = 42

# %% [markdown]
# Let's looks at the search algorithm structure
#
# `RegexSettings` is a tree/'directory' object that contains  `RegexSettings`s, `RegexBlueprint`s and `RegexRequest`s. `RegexBlueprint` is a 'generator' object for `RegexRequest`s of the same type. They have `.items` that contains `RegexRequest`s as it was previously shown.

# %%
rs = chp.RegexSettings(chp.DEFAULT_ORCA_REGEX_FILE)
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaTotalRunTime: RegexRequest(p_type='Block', p_subtype='BlockOrcaTotalRunTime', pattern='^([ \t]*TOTAL RUN TIME...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaTerminatedNormally: RegexRequest(p_type='Block', p_subtype='BlockOrcaTerminatedNormally', pattern='^([ \t]*\*{4}ORCA TERM...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type='Block', p_subtype='BlockOrcaFinalSinglePointEnergy', pattern='^((-{20,}\s+-{15,}\n)[...', flags=re.MULTILINE, comment='This pattern matches t...')
#       BlockOrcaDipoleMoment: RegexRequest(p_type='Block', p_subtype='BlockOrcaDipoleMoment', pattern='^(([ \t]*-{10,}[ \t]*\...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaInputFile: RegexRequest(p_type='Block', p_subtype='BlockOrcaInputFile', pattern='^((?:[ \t]*={10,}[ \t]...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaShark: RegexRequest(p_type='Block', p_subtype='BlockOrcaShark', pattern='^((?:[ \t]*-{50,}[ \t]...', flags=re.MULTILINE, comment='Starts with line of  -...')
#       BlockOrcaWarnings: RegexRequest(p_type='Block', p_subtype='BlockOrcaWarnings', pattern='^((?:[ \t]*\={5,}[ \t]...', flags=re.MULTILINE, comment='WARNINGS, should captu...')
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*Rotational spectrum[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaOrbitalEnergies: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*ORBITAL ENERGIES[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTotalScfEnergy: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TOTAL SCF ENERGY[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTddftExcitedStatesSinglets: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TD-DFT EXCITED STATES \(SINGLETS\)[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#       BlueprintBlockWithInlineHeader:
#         RegexBlueprint:
#           BlockOrcaOrbitalBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*Orbital basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAuxJBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*AuxJ basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockNote:
#         RegexBlueprint:
#           BlockOrcaAllRightsReserved: Pattern: ^((?:[ \t]*(([\-\*\#\=]){5,})[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(^[ \t]*\3[ \t]*All rights reserved[ \t]*\3[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(?:[ \t]*\2[ \t]*\n))
#       BlueprintBlockSCF:
#         RegexBlueprint:
#           BlockOrcaScf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaSoscf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-O-S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlockOrcaScfConverged: RegexRequest(p_type='Block', p_subtype='BlockOrcaScfConverged', pattern='^((?:[ \t]*\*{5,}[ \t]...', flags=re.MULTILINE, comment='Note, but with CF CONV...')
#       BlockOrcaIcon: RegexRequest(p_type='Block', p_subtype='BlockOrcaIcon', pattern='^((?:^[ \t]*#,[ \t]*\n...', flags=re.MULTILINE, comment='Unsafe as can ignore t...')
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithSingeLineHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithSingeLineHeader', pattern='^((?:^[ \t]*[\-\*\#\=]...', flags=re.MULTILINE, comment='Block starts with a li...')
#       BlockOrcaUnrecognizedWithHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithHeader', pattern='(([ \t]*[\-\*\#\=]{5,}...', flags=re.MULTILINE, comment='Special, from 1 to 3 n...')
#   Spacer: RegexRequest(p_type='Spacer', p_subtype='Spacer', pattern='^(\s*\n)', flags=re.MULTILINE, comment='Just some empty lines,...')

# %% [markdown]
# You can create the new instance of `RegexSettings`, `RegexBlueprint` or `RegexRequest` and add it with .add_item.
#
# `TypeKnownBlocks` is made for specific patterns for known blocks
#
# `TypeDefaultBlocks` is made for the general patters to find some specific kinds of blocks, data extraction is not expected from the blocks in this section
#
# `BlockOrcaUnknown` is the `RegexRequest` to collect everything that was not recognized before as a block and is not just a space
#
# `Spacer` collects the spaces left in the document

# %%
pattern = chp.regex_request.RegexRequest(
    p_type="Block",
    p_subtype="BlockOrcaDemonstration",
    pattern="^(aaa)$",
    flags=["MULTILINE"],
    comment="Patterns should always start with ^, have at least 1 capturing group and end with $",
)
pattern
# Out:
# RegexRequest(p_type='Block', p_subtype='BlockOrcaDemonstration', pattern='^(aaa)$', flags=re.MULTILINE, comment='Patterns should always...')

# %% [markdown]
# Patterns should always start with `^`, have at least 1 capturing group and end with `$`. This capturing group will capture the `raw_data`

# %%
rs.items["TypeKnownBlocks"].add_item(name="BlockOrcaDemonstration", item=pattern)

# %% [markdown]
# Pattern was successfully added:

# %%
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaTotalRunTime: RegexRequest(p_type='Block', p_subtype='BlockOrcaTotalRunTime', pattern='^([ \t]*TOTAL RUN TIME...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaTerminatedNormally: RegexRequest(p_type='Block', p_subtype='BlockOrcaTerminatedNormally', pattern='^([ \t]*\*{4}ORCA TERM...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type='Block', p_subtype='BlockOrcaFinalSinglePointEnergy', pattern='^((-{20,}\s+-{15,}\n)[...', flags=re.MULTILINE, comment='This pattern matches t...')
#       BlockOrcaDipoleMoment: RegexRequest(p_type='Block', p_subtype='BlockOrcaDipoleMoment', pattern='^(([ \t]*-{10,}[ \t]*\...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaInputFile: RegexRequest(p_type='Block', p_subtype='BlockOrcaInputFile', pattern='^((?:[ \t]*={10,}[ \t]...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaShark: RegexRequest(p_type='Block', p_subtype='BlockOrcaShark', pattern='^((?:[ \t]*-{50,}[ \t]...', flags=re.MULTILINE, comment='Starts with line of  -...')
#       BlockOrcaWarnings: RegexRequest(p_type='Block', p_subtype='BlockOrcaWarnings', pattern='^((?:[ \t]*\={5,}[ \t]...', flags=re.MULTILINE, comment='WARNINGS, should captu...')
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*Rotational spectrum[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaOrbitalEnergies: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*ORBITAL ENERGIES[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTotalScfEnergy: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TOTAL SCF ENERGY[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTddftExcitedStatesSinglets: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TD-DFT EXCITED STATES \(SINGLETS\)[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#       BlueprintBlockWithInlineHeader:
#         RegexBlueprint:
#           BlockOrcaOrbitalBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*Orbital basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAuxJBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*AuxJ basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockNote:
#         RegexBlueprint:
#           BlockOrcaAllRightsReserved: Pattern: ^((?:[ \t]*(([\-\*\#\=]){5,})[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(^[ \t]*\3[ \t]*All rights reserved[ \t]*\3[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(?:[ \t]*\2[ \t]*\n))
#       BlueprintBlockSCF:
#         RegexBlueprint:
#           BlockOrcaScf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaSoscf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-O-S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlockOrcaScfConverged: RegexRequest(p_type='Block', p_subtype='BlockOrcaScfConverged', pattern='^((?:[ \t]*\*{5,}[ \t]...', flags=re.MULTILINE, comment='Note, but with CF CONV...')
#       BlockOrcaIcon: RegexRequest(p_type='Block', p_subtype='BlockOrcaIcon', pattern='^((?:^[ \t]*#,[ \t]*\n...', flags=re.MULTILINE, comment='Unsafe as can ignore t...')
#       BlockOrcaDemonstration: RegexRequest(p_type='Block', p_subtype='BlockOrcaDemonstration', pattern='^(aaa)$', flags=re.MULTILINE, comment='Patterns should always...')
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithSingeLineHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithSingeLineHeader', pattern='^((?:^[ \t]*[\-\*\#\=]...', flags=re.MULTILINE, comment='Block starts with a li...')
#       BlockOrcaUnrecognizedWithHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithHeader', pattern='(([ \t]*[\-\*\#\=]{5,}...', flags=re.MULTILINE, comment='Special, from 1 to 3 n...')
#   Spacer: RegexRequest(p_type='Spacer', p_subtype='Spacer', pattern='^(\s*\n)', flags=re.MULTILINE, comment='Just some empty lines,...')
