# %%
import re

import chemparse as chp

# %% [markdown]
# `My data` and `Another data` blocks were recognized as `BlockOrcaUnrecognizedWithHeader` and `My start of the message messag` block was recognized as `BlockUnknown`

# %%
orca_file = chp.File("example.out")
orca_file.get_data()
# Out:
# 2024-04-04 20:21:53,049 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#
# 2024-04-04 20:21:53,050 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#
# 2024-04-04 20:21:53,050 - chemparse - WARNING - The block looks unstructured. Please contribute to the project if you have knowledge on how to extract data from it.
#                  Type                                   Subtype  \
# 7764716181144   Block                     BlockOrcaTotalRunTime
# 7764716181282   Block               BlockOrcaTerminatedNormally
# 7764716181207   Block           BlockOrcaFinalSinglePointEnergy
# 7764716181393   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 7764716181333   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 7764716181444  Spacer                                    Spacer
# 7764716181102  Spacer                                    Spacer
# 7764716181129  Spacer                                    Spacer
# 7764716180988   Block                              BlockUnknown
#
#                                                          Element CharPosition  \
# 7764716181144  <chemparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7764716181282  <chemparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 7764716181207  <chemparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7764716181393  <chemparse.orca_elements.BlockOrcaUnrecognized...    (45, 116)
# 7764716181333  <chemparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 7764716181444  <chemparse.elements.Spacer object at 0x70fdd26...       (0, 0)
# 7764716181102  <chemparse.elements.Spacer object at 0x70fdd26...     (44, 44)
# 7764716181129  <chemparse.elements.Spacer object at 0x70fdd26...   (501, 502)
# 7764716180988  <chemparse.elements.BlockUnknown object at 0x7...      (1, 43)
#
#               LinePosition                       ReadableName  \
# 7764716181144     (24, 25)                     TOTAL RUN TIME
# 7764716181282     (23, 24)           ORCA TERMINATED NORMALLY
# 7764716181207     (18, 21)          FINAL SINGLE POINT ENERGY
# 7764716181393      (6, 12)                            My data
# 7764716181333     (13, 19)                       Another data
# 7764716181444       (1, 2)                               None
# 7764716181102       (6, 7)                               None
# 7764716181129     (22, 24)                               None
# 7764716180988       (3, 5)  My start of the message messag...
#
#                                                          RawData  \
# 7764716181144  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7764716181282                               ****ORCA TERMINAT...
# 7764716181207  -------------------------   ------------------...
# 7764716181393  --------------------\nMy data\n---------------...
# 7764716181333                              ******************...
# 7764716181444                                                 \n
# 7764716181102                                                 \n
# 7764716181129                                               \n\n
# 7764716180988      My start of the message: message1\nmessage2\n
#
#                       ExtractedData
# 7764716181144            [Run Time]
# 7764716181282  [Termination status]
# 7764716181207              [Energy]
# 7764716181393            [raw data]
# 7764716181333            [raw data]
# 7764716181444                  None
# 7764716181102                  None
# 7764716181129                  None
# 7764716180988            [raw data]

# %% [markdown]
# Let's start with the simple ways of introducing your block, and later we will discuss the structure os the search and use the more advanced methods

# %%
rs = chp.RegexSettings(chp.DEFAULT_ORCA_REGEX_FILE)

# %% [markdown]
# `My data` and `Another data` blocks have quite a standard pattern: Single Line Header

# %% [markdown]
# Lets add `My data` to the blueprint for this type of patterns
# Use BlockNameOfBlock for the class name

# %%
rs.items["TypeKnownBlocks"].items["BlueprintBlockWithSingeLineHeader"].add_item(
    name="BlockOrcaMyData", pattern_text="My data"
)

# %% [markdown]
# We will detect the first block as paragraph that starts with 'My start of the message'

# %%
rs.items["TypeKnownBlocks"].items["BlueprintParagraphStartsWith"].add_item(
    name="BlockOrcaMyStart", pattern_text="My start of the message"
)

# %% [markdown]
# Let's look at the changes.
#
# We should load our new regex settings file at the creation of `File` object

# %%
orca_file = chp.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# 2024-04-04 20:21:53,089 - chemparse - WARNING - Subtype `BlockOrcaMyStart` not recognized. Falling back to Block.
# 2024-04-04 20:21:53,093 - chemparse - WARNING - Subtype `BlockOrcaMyData` not recognized. Falling back to Block.
# 2024-04-04 20:21:53,102 - chemparse - WARNING - No procedure for analyzing the data found in type `Block`, returning the raw data:
# My start of the message: message1
# message2
#
# 2024-04-04 20:21:53,102 - chemparse - WARNING - No procedure for analyzing the data found in type `Block`, returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#
# 2024-04-04 20:21:53,103 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#                  Type                                   Subtype  \
# 7764716074321   Block                     BlockOrcaTotalRunTime
# 7764716074258   Block               BlockOrcaTerminatedNormally
# 7764716074342   Block           BlockOrcaFinalSinglePointEnergy
# 7764716181075   Block                          BlockOrcaMyStart
# 7764716074441   Block                           BlockOrcaMyData
# 7764716074231   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 7764716074408  Spacer                                    Spacer
# 7764716074375  Spacer                                    Spacer
# 7764716074459  Spacer                                    Spacer
#
#                                                          Element CharPosition  \
# 7764716074321  <chemparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7764716074258  <chemparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 7764716074342  <chemparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7764716181075  <chemparse.elements.Block object at 0x70fdd265...      (1, 43)
# 7764716074441  <chemparse.elements.Block object at 0x70fdd24b...    (45, 116)
# 7764716074231  <chemparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 7764716074408  <chemparse.elements.Spacer object at 0x70fdd24...       (0, 0)
# 7764716074375  <chemparse.elements.Spacer object at 0x70fdd24...     (44, 44)
# 7764716074459  <chemparse.elements.Spacer object at 0x70fdd24...   (501, 502)
#
#               LinePosition                       ReadableName  \
# 7764716074321     (24, 25)                     TOTAL RUN TIME
# 7764716074258     (23, 24)           ORCA TERMINATED NORMALLY
# 7764716074342     (18, 21)          FINAL SINGLE POINT ENERGY
# 7764716181075       (3, 5)  My start of the message messag...
# 7764716074441      (8, 14)               My data My value eV
# 7764716074231     (15, 21)                       Another data
# 7764716074408       (1, 2)                               None
# 7764716074375       (6, 7)                               None
# 7764716074459     (22, 24)                               None
#
#                                                          RawData  \
# 7764716074321  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7764716074258                               ****ORCA TERMINAT...
# 7764716074342  -------------------------   ------------------...
# 7764716181075      My start of the message: message1\nmessage2\n
# 7764716074441  --------------------\nMy data\n---------------...
# 7764716074231                              ******************...
# 7764716074408                                                 \n
# 7764716074375                                                 \n
# 7764716074459                                               \n\n
#
#                       ExtractedData
# 7764716074321            [Run Time]
# 7764716074258  [Termination status]
# 7764716074342              [Energy]
# 7764716181075            [raw data]
# 7764716074441            [raw data]
# 7764716074231            [raw data]
# 7764716074408                  None
# 7764716074375                  None
# 7764716074459                  None

# %% [markdown]
# The Blocks were recognized as `BlockOrcaMyStart` and `BlockOrcaMyData`
#
# Now let's add the data recognition to `BlockOrcaMyData`
#
# Note that I am using `BlockOrcaWithStandardHeader` instead of just `Block`, as I know that this block has a standard header that can be easily separated. But I could use `Block`, then `ReadableName` would be recognized as 'My data My value eV'  instead of 'My data'
#
# Data extraction takes place only on a call, so you don't need to worry much about the performance of your code

# %%
@chp.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyData(chp.orca_elements.BlockOrcaWithStandardHeader):

    def data(self):
        pattern = r"My value:\s*(\d+\.\d+)"
        match = re.search(pattern, self.raw_data)
        extracted_number = float(match.group(1)) if match else None
        value = extracted_number * chp.units_and_constants.ureg.eV
        return chp.Data(
            data={
                "My value": value,
                "Another Value": 42
            },
            comment=
            "Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude\n`Another value` is 42.",
        )

# %% [markdown]
# Now lets add the `ReadableName` to `BlockOrcaMyStart`. Now it is 'My start of the message messag...'

# %%
@chp.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyStart(chp.elements.Block):

    def extract_name_header_and_body(self):
        return "My Start", None, self.raw_data

# %% [markdown]
# Do not forget to restart the orca file

# %%
orca_file = chp.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# 2024-04-04 20:21:53,141 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaMyStart`, returning the raw data:
# My start of the message: message1
# message2
#
# 2024-04-04 20:21:53,142 - chemparse - WARNING - No procedure for analyzing the data found in type `BlockOrcaUnrecognizedWithSingeLineHeader`, returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#                  Type                                   Subtype  \
# 7764716074519   Block                     BlockOrcaTotalRunTime
# 7764716074528   Block               BlockOrcaTerminatedNormally
# 7764716074840   Block           BlockOrcaFinalSinglePointEnergy
# 7764716074633   Block                          BlockOrcaMyStart
# 7764716074738   Block                           BlockOrcaMyData
# 7764716074780   Block  BlockOrcaUnrecognizedWithSingeLineHeader
# 7764716074636  Spacer                                    Spacer
# 7764716074531  Spacer                                    Spacer
# 7764716074624  Spacer                                    Spacer
#
#                                                          Element CharPosition  \
# 7764716074519  <chemparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7764716074528  <chemparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 7764716074840  <chemparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7764716074633  <__main__.BlockOrcaMyStart object at 0x70fdd24...      (1, 43)
# 7764716074738  <__main__.BlockOrcaMyData object at 0x70fdd24b...    (45, 116)
# 7764716074780  <chemparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 7764716074636  <chemparse.elements.Spacer object at 0x70fdd24...       (0, 0)
# 7764716074531  <chemparse.elements.Spacer object at 0x70fdd24...     (44, 44)
# 7764716074624  <chemparse.elements.Spacer object at 0x70fdd24...   (501, 502)
#
#               LinePosition               ReadableName  \
# 7764716074519     (24, 25)             TOTAL RUN TIME
# 7764716074528     (23, 24)   ORCA TERMINATED NORMALLY
# 7764716074840     (18, 21)  FINAL SINGLE POINT ENERGY
# 7764716074633       (3, 5)                   My Start
# 7764716074738      (8, 14)                    My data
# 7764716074780     (15, 21)               Another data
# 7764716074636       (1, 2)                       None
# 7764716074531       (6, 7)                       None
# 7764716074624     (22, 24)                       None
#
#                                                          RawData  \
# 7764716074519  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7764716074528                               ****ORCA TERMINAT...
# 7764716074840  -------------------------   ------------------...
# 7764716074633      My start of the message: message1\nmessage2\n
# 7764716074738  --------------------\nMy data\n---------------...
# 7764716074780                              ******************...
# 7764716074636                                                 \n
# 7764716074531                                                 \n
# 7764716074624                                               \n\n
#
#                            ExtractedData
# 7764716074519                 [Run Time]
# 7764716074528       [Termination status]
# 7764716074840                   [Energy]
# 7764716074633                 [raw data]
# 7764716074738  [My value, Another Value]
# 7764716074780                 [raw data]
# 7764716074636                       None
# 7764716074531                       None
# 7764716074624                       None

# %% [markdown]
# Now our data is ready to be extracted:

# %%
df = orca_file.get_data(element_type=BlockOrcaMyData)
display(df)
assert len(df) == 1, "More then 1 `BlockOrcaMyData` found"
data = df.iloc[0].ExtractedData
print(data)
print()
print(f"{data['My value'].magnitude = }")
print(f"{data['Another Value'] = }")
# Out:
#                 Type          Subtype  \
# 7764716074738  Block  BlockOrcaMyData
#
#                                                          Element CharPosition  \
# 7764716074738  <__main__.BlockOrcaMyData object at 0x70fdd24b...    (45, 116)
#
#               LinePosition ReadableName  \
# 7764716074738      (8, 14)      My data
#
#                                                          RawData  \
# 7764716074738  --------------------\nMy data\n---------------...
#
#                            ExtractedData
# 7764716074738  [My value, Another Value]
# Data with items: `My value`, `Another Value`. Comment: Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude
# `Another value` is 42.
#
# data['My value'].magnitude = 1.234
# data['Another Value'] = 42

# %% [markdown]
# Let's looks at the search algorithm structure
#
# `RegexSettings` is a tree/'directory' object that contains  `RegexSettings`s, `RegexBlueprint`s and `RegexRequest`s. `RegexBlueprint` is a 'generator' object for `RegexRequest`s of the same type. They have `.items` that contains `RegexRequest`s as it was previously shown.

# %%
rs = chp.RegexSettings(chp.DEFAULT_ORCA_REGEX_FILE)
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaTotalRunTime: RegexRequest(p_type='Block', p_subtype='BlockOrcaTotalRunTime', pattern='^([ \t]*TOTAL RUN TIME...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaTerminatedNormally: RegexRequest(p_type='Block', p_subtype='BlockOrcaTerminatedNormally', pattern='^([ \t]*\*{4}ORCA TERM...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type='Block', p_subtype='BlockOrcaFinalSinglePointEnergy', pattern='^((-{20,}\s+-{15,}\n)[...', flags=re.MULTILINE, comment='This pattern matches t...')
#       BlockOrcaDipoleMoment: RegexRequest(p_type='Block', p_subtype='BlockOrcaDipoleMoment', pattern='^(([ \t]*-{10,}[ \t]*\...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaInputFile: RegexRequest(p_type='Block', p_subtype='BlockOrcaInputFile', pattern='^((?:[ \t]*={10,}[ \t]...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaShark: RegexRequest(p_type='Block', p_subtype='BlockOrcaShark', pattern='^((?:[ \t]*-{50,}[ \t]...', flags=re.MULTILINE, comment='Starts with line of  -...')
#       BlockOrcaWarnings: RegexRequest(p_type='Block', p_subtype='BlockOrcaWarnings', pattern='^((?:[ \t]*\={5,}[ \t]...', flags=re.MULTILINE, comment='WARNINGS, should captu...')
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*Rotational spectrum[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaOrbitalEnergies: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*ORBITAL ENERGIES[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTotalScfEnergy: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TOTAL SCF ENERGY[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTddftExcitedStatesSinglets: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TD-DFT EXCITED STATES \(SINGLETS\)[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#       BlueprintBlockWithInlineHeader:
#         RegexBlueprint:
#           BlockOrcaOrbitalBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*Orbital basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAuxJBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*AuxJ basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockNote:
#         RegexBlueprint:
#           BlockOrcaAllRightsReserved: Pattern: ^((?:[ \t]*(([\-\*\#\=]){5,})[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(^[ \t]*\3[ \t]*All rights reserved[ \t]*\3[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(?:[ \t]*\2[ \t]*\n))
#       BlueprintBlockSCF:
#         RegexBlueprint:
#           BlockOrcaScf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaSoscf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-O-S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlockOrcaScfConverged: RegexRequest(p_type='Block', p_subtype='BlockOrcaScfConverged', pattern='^((?:[ \t]*\*{5,}[ \t]...', flags=re.MULTILINE, comment='Note, but with CF CONV...')
#       BlockOrcaIcon: RegexRequest(p_type='Block', p_subtype='BlockOrcaIcon', pattern='^((?:^[ \t]*#,[ \t]*\n...', flags=re.MULTILINE, comment='Unsafe as can ignore t...')
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithSingeLineHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithSingeLineHeader', pattern='^((?:^[ \t]*[\-\*\#\=]...', flags=re.MULTILINE, comment='Block starts with a li...')
#       BlockOrcaUnrecognizedWithHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithHeader', pattern='(([ \t]*[\-\*\#\=]{5,}...', flags=re.MULTILINE, comment='Special, from 1 to 3 n...')
#   Spacer: RegexRequest(p_type='Spacer', p_subtype='Spacer', pattern='^(\s*\n)', flags=re.MULTILINE, comment='Just some empty lines,...')

# %% [markdown]
# You can create the new instance of `RegexSettings`, `RegexBlueprint` or `RegexRequest` and add it with .add_item.
#
# `TypeKnownBlocks` is made for specific patterns for known blocks
#
# `TypeDefaultBlocks` is made for the general patters to find some specific kinds of blocks, data extraction is not expected from the blocks in this section
#
# `BlockOrcaUnknown` is the `RegexRequest` to collect everything that was not recognized before as a block and is not just a space
#
# `Spacer` collects the spaces left in the document

# %%
pattern = chp.regex_request.RegexRequest(
    p_type="Block",
    p_subtype="BlockOrcaDemonstration",
    pattern="^(aaa)$",
    flags=["MULTILINE"],
    comment=
    "Patterns should always start with ^, have at least 1 capturing group and end with $",
)
pattern
# Out:
# RegexRequest(p_type='Block', p_subtype='BlockOrcaDemonstration', pattern='^(aaa)$', flags=re.MULTILINE, comment='Patterns should always...')

# %% [markdown]
# Patterns should always start with `^`, have at least 1 capturing group and end with `$`. This capturing group will capture the `raw_data`

# %%
rs.items["TypeKnownBlocks"].add_item(
    name="BlockOrcaDemonstration", item=pattern)

# %% [markdown]
# Pattern was successfully added:

# %%
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaTotalRunTime: RegexRequest(p_type='Block', p_subtype='BlockOrcaTotalRunTime', pattern='^([ \t]*TOTAL RUN TIME...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaTerminatedNormally: RegexRequest(p_type='Block', p_subtype='BlockOrcaTerminatedNormally', pattern='^([ \t]*\*{4}ORCA TERM...', flags=re.MULTILINE, comment='This pattern captures ...')
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type='Block', p_subtype='BlockOrcaFinalSinglePointEnergy', pattern='^((-{20,}\s+-{15,}\n)[...', flags=re.MULTILINE, comment='This pattern matches t...')
#       BlockOrcaDipoleMoment: RegexRequest(p_type='Block', p_subtype='BlockOrcaDipoleMoment', pattern='^(([ \t]*-{10,}[ \t]*\...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaInputFile: RegexRequest(p_type='Block', p_subtype='BlockOrcaInputFile', pattern='^((?:[ \t]*={10,}[ \t]...', flags=re.MULTILINE, comment='Equal signs around the...')
#       BlockOrcaShark: RegexRequest(p_type='Block', p_subtype='BlockOrcaShark', pattern='^((?:[ \t]*-{50,}[ \t]...', flags=re.MULTILINE, comment='Starts with line of  -...')
#       BlockOrcaWarnings: RegexRequest(p_type='Block', p_subtype='BlockOrcaWarnings', pattern='^((?:[ \t]*\={5,}[ \t]...', flags=re.MULTILINE, comment='WARNINGS, should captu...')
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*Rotational spectrum[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaOrbitalEnergies: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*ORBITAL ENERGIES[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTotalScfEnergy: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TOTAL SCF ENERGY[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#           BlockOrcaTddftExcitedStatesSinglets: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*TD-DFT EXCITED STATES \(SINGLETS\)[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#       BlueprintBlockWithInlineHeader:
#         RegexBlueprint:
#           BlockOrcaOrbitalBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*Orbital basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAuxJBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*AuxJ basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockNote:
#         RegexBlueprint:
#           BlockOrcaAllRightsReserved: Pattern: ^((?:[ \t]*(([\-\*\#\=]){5,})[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(^[ \t]*\3[ \t]*All rights reserved[ \t]*\3[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(?:[ \t]*\2[ \t]*\n))
#       BlueprintBlockSCF:
#         RegexBlueprint:
#           BlockOrcaScf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaSoscf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-O-S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlockOrcaScfConverged: RegexRequest(p_type='Block', p_subtype='BlockOrcaScfConverged', pattern='^((?:[ \t]*\*{5,}[ \t]...', flags=re.MULTILINE, comment='Note, but with CF CONV...')
#       BlockOrcaIcon: RegexRequest(p_type='Block', p_subtype='BlockOrcaIcon', pattern='^((?:^[ \t]*#,[ \t]*\n...', flags=re.MULTILINE, comment='Unsafe as can ignore t...')
#       BlockOrcaDemonstration: RegexRequest(p_type='Block', p_subtype='BlockOrcaDemonstration', pattern='^(aaa)$', flags=re.MULTILINE, comment='Patterns should always...')
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithSingeLineHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithSingeLineHeader', pattern='^((?:^[ \t]*[\-\*\#\=]...', flags=re.MULTILINE, comment='Block starts with a li...')
#       BlockOrcaUnrecognizedWithHeader: RegexRequest(p_type='Block', p_subtype='BlockOrcaUnrecognizedWithHeader', pattern='(([ \t]*[\-\*\#\=]{5,}...', flags=re.MULTILINE, comment='Special, from 1 to 3 n...')
#   Spacer: RegexRequest(p_type='Spacer', p_subtype='Spacer', pattern='^(\s*\n)', flags=re.MULTILINE, comment='Just some empty lines,...')
