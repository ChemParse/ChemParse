# %%
import re

import orcaparse as op

# %% [markdown]
# `My data` and `Another data` blocks were recognized as `BlockOrcaUnrecognizedWithHeader` and `My start of the message messag` block was recognized as `BlockUnknown`

# %%
orca_file = op.File("example.out")
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedWithHeader'>`,returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedWithHeader'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:343: UserWarning: The block looks not structured. Please contribute to the project if you have knowledge on how to extract data from it.
#   warnings.warn(
#                  Type                          Subtype  \
# 7892854203365   Block            BlockOrcaTotalRunTime
# 7892854238236   Block      BlockOrcaTerminatedNormally
# 7892854238305   Block  BlockOrcaFinalSinglePointEnergy
# 7892854238254   Block  BlockOrcaUnrecognizedWithHeader
# 7892854238779   Block  BlockOrcaUnrecognizedWithHeader
# 7892854238398  Spacer                           Spacer
# 7892854238308  Spacer                           Spacer
# 7892854238452  Spacer                           Spacer
# 7892854203191   Block                     BlockUnknown
#
#                                                          Element CharPosition  \
# 7892854203365  <orcaparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7892854238236  <orcaparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 7892854238305  <orcaparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7892854238254  <orcaparse.orca_elements.BlockOrcaUnrecognized...    (45, 116)
# 7892854238779  <orcaparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 7892854238398  <orcaparse.elements.Spacer object at 0x72db2c5...       (0, 0)
# 7892854238308  <orcaparse.elements.Spacer object at 0x72db2c5...     (44, 44)
# 7892854238452  <orcaparse.elements.Spacer object at 0x72db2c5...   (501, 502)
# 7892854203191  <orcaparse.elements.BlockUnknown object at 0x7...      (1, 43)
#
#               LinePosition                       ReadableName  \
# 7892854203365     (24, 25)                     TOTAL RUN TIME
# 7892854238236     (23, 24)           ORCA TERMINATED NORMALLY
# 7892854238305     (18, 21)          FINAL SINGLE POINT ENERGY
# 7892854238254      (6, 12)                            My data
# 7892854238779     (13, 19)                       Another data
# 7892854238398       (1, 2)                               None
# 7892854238308       (6, 7)                               None
# 7892854238452     (22, 24)                               None
# 7892854203191       (3, 5)  My start of the message messag...
#
#                                                          RawData  \
# 7892854203365  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7892854238236                               ****ORCA TERMINAT...
# 7892854238305  -------------------------   ------------------...
# 7892854238254  --------------------\nMy data\n---------------...
# 7892854238779                              ******************...
# 7892854238398                                                 \n
# 7892854238308                                                 \n
# 7892854238452                                               \n\n
# 7892854203191      My start of the message: message1\nmessage2\n
#
#                       ExtractedData
# 7892854203365            [Run Time]
# 7892854238236  [Termination status]
# 7892854238305              [Energy]
# 7892854238254            [raw data]
# 7892854238779            [raw data]
# 7892854238398                  None
# 7892854238308                  None
# 7892854238452                  None
# 7892854203191            [raw data]

# %% [markdown]
# Let's start with the simple ways of introducing your block, and later we will discuss the structure os the search and use the more advanced methods

# %%
rs = op.RegexSettings(op.DEFAULT_ORCA_REGEX_FILE)

# %% [markdown]
# `My data` and `Another data` blocks have quite a standard pattern: Single Line Header

# %% [markdown]
# Lets add `My data` to the blueprint for this type of patterns
# Use BlockNameOfBlock for the class name

# %%
rs.items["TypeKnownBlocks"].items[
    "BlueprintBlockWithSingeLineHeader"].add_item(name="BlockOrcaMyData",
                                                  pattern_text="My data")

# %% [markdown]
# We will detect the first block as paragraph that starts with 'My start of the message'

# %%
rs.items["TypeKnownBlocks"].items["BlueprintParagraphStartsWith"].add_item(
    name="BlockOrcaMyStart", pattern_text="My start of the message")

# %% [markdown]
# Let's look at the changes.
#
# We should load our new regex settings file at the creation of `File` object

# %%
orca_file = op.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/regex_request.py:221: UserWarning: Subtype `BlockOrcaMyStart` not recognized. Falling back to Block.
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/regex_request.py:221: UserWarning: Subtype `BlockOrcaMyData` not recognized. Falling back to Block.
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.Block'>`,returning the raw data:
# My start of the message: message1
# message2
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.elements.Block'>`,returning the raw data:
# --------------------
# My data
# --------------------
#
# My value: 1.234 eV
#
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedWithHeader'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#
#   warnings.warn(
#                  Type                          Subtype  \
# 7892854238578   Block            BlockOrcaTotalRunTime
# 7892854238461   Block      BlockOrcaTerminatedNormally
# 7892854238851   Block  BlockOrcaFinalSinglePointEnergy
# 7892854238815   Block                 BlockOrcaMyStart
# 7892854238803   Block                  BlockOrcaMyData
# 7892854238971   Block  BlockOrcaUnrecognizedWithHeader
# 7892854238941  Spacer                           Spacer
# 7892854238992  Spacer                           Spacer
# 7892854238968  Spacer                           Spacer
#
#                                                          Element CharPosition  \
# 7892854238578  <orcaparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7892854238461  <orcaparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 7892854238851  <orcaparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7892854238815  <orcaparse.elements.Block object at 0x72db2c5e...      (1, 43)
# 7892854238803  <orcaparse.elements.Block object at 0x72db2c5e...    (45, 116)
# 7892854238971  <orcaparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 7892854238941  <orcaparse.elements.Spacer object at 0x72db2c5...       (0, 0)
# 7892854238992  <orcaparse.elements.Spacer object at 0x72db2c5...     (44, 44)
# 7892854238968  <orcaparse.elements.Spacer object at 0x72db2c5...   (501, 502)
#
#               LinePosition                       ReadableName  \
# 7892854238578     (24, 25)                     TOTAL RUN TIME
# 7892854238461     (23, 24)           ORCA TERMINATED NORMALLY
# 7892854238851     (18, 21)          FINAL SINGLE POINT ENERGY
# 7892854238815       (3, 5)  My start of the message messag...
# 7892854238803      (8, 14)               My data My value eV
# 7892854238971     (15, 21)                       Another data
# 7892854238941       (1, 2)                               None
# 7892854238992       (6, 7)                               None
# 7892854238968     (22, 24)                               None
#
#                                                          RawData  \
# 7892854238578  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7892854238461                               ****ORCA TERMINAT...
# 7892854238851  -------------------------   ------------------...
# 7892854238815      My start of the message: message1\nmessage2\n
# 7892854238803  --------------------\nMy data\n---------------...
# 7892854238971                              ******************...
# 7892854238941                                                 \n
# 7892854238992                                                 \n
# 7892854238968                                               \n\n
#
#                       ExtractedData
# 7892854238578            [Run Time]
# 7892854238461  [Termination status]
# 7892854238851              [Energy]
# 7892854238815            [raw data]
# 7892854238803            [raw data]
# 7892854238971            [raw data]
# 7892854238941                  None
# 7892854238992                  None
# 7892854238968                  None

# %% [markdown]
# The Blocks were recognized as `BlockOrcaMyStart` and `BlockOrcaMyData`
#
# Now let's add the data recognition to `BlockOrcaMyData`
#
# Note that I am using `BlockOrcaWithStandardHeader` instead of just `Block`, as I know that this block has a standard header that can be easily separated. But I could use `Block`, then `ReadableName` would be recognized as 'My data My value eV'  instead of 'My data'
#
# Data extraction takes place only on a call, so you don't need to worry much about the performance of your code

# %%
@op.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyData(op.orca_elements.BlockOrcaWithStandardHeader):

    def data(self):
        pattern = r"My value:\s*(\d+\.\d+)"
        match = re.search(pattern, self.raw_data)
        extracted_number = float(match.group(1)) if match else None
        value = extracted_number * op.units_and_constants.ureg.eV
        return op.Data(
            data={
                "My value": value,
                "Another Value": 42
            },
            comment="Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude\n`Another value` is 42.",
        )

# %% [markdown]
# Now lets add the `ReadableName` to `BlockOrcaMyStart`. Now it is 'My start of the message messag...'

# %%
@op.orca_elements.AvailableBlocksOrca.register_block
class BlockOrcaMyStart(op.elements.Block):

    def extract_name_header_and_body(self):
        return "My Start", None, self.raw_data

# %% [markdown]
# Do not forget to restart the orca file

# %%
orca_file = op.File("example.out", regex_settings=rs)
orca_file.get_data()
# Out:
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class '__main__.BlockOrcaMyStart'>`,returning the raw data:
# My start of the message: message1
# message2
#
#   warnings.warn(
# /home/ivan/Projects/OrcaParse/orcaparse/elements.py:64: UserWarning: No procedure for analyzing the data found in type `<class 'orcaparse.orca_elements.BlockOrcaUnrecognizedWithHeader'>`,returning the raw data:
#                             ***************************************
#                             *            Another data             *
#                             ***************************************
# Not my match
# My value: 9.876 eV
#
#
#   warnings.warn(
#                  Type                          Subtype  \
# 7892854239037   Block            BlockOrcaTotalRunTime
# 7892854239088   Block      BlockOrcaTerminatedNormally
# 7892854239181   Block  BlockOrcaFinalSinglePointEnergy
# 7892854239127   Block                 BlockOrcaMyStart
# 7892854239121   Block                  BlockOrcaMyData
# 7892854238833   Block  BlockOrcaUnrecognizedWithHeader
# 7892854239094  Spacer                           Spacer
# 7892854239148  Spacer                           Spacer
# 7892854238872  Spacer                           Spacer
#
#                                                          Element CharPosition  \
# 7892854239037  <orcaparse.orca_elements.BlockOrcaTotalRunTime...   (565, 625)
# 7892854239088  <orcaparse.orca_elements.BlockOrcaTerminatedNo...   (503, 564)
# 7892854239181  <orcaparse.orca_elements.BlockOrcaFinalSingleP...   (354, 500)
# 7892854239127  <__main__.BlockOrcaMyStart object at 0x72db2c5...      (1, 43)
# 7892854239121  <__main__.BlockOrcaMyData object at 0x72db2c5e...    (45, 116)
# 7892854238833  <orcaparse.orca_elements.BlockOrcaUnrecognized...   (117, 353)
# 7892854239094  <orcaparse.elements.Spacer object at 0x72db2c5...       (0, 0)
# 7892854239148  <orcaparse.elements.Spacer object at 0x72db2c5...     (44, 44)
# 7892854238872  <orcaparse.elements.Spacer object at 0x72db2c5...   (501, 502)
#
#               LinePosition               ReadableName  \
# 7892854239037     (24, 25)             TOTAL RUN TIME
# 7892854239088     (23, 24)   ORCA TERMINATED NORMALLY
# 7892854239181     (18, 21)  FINAL SINGLE POINT ENERGY
# 7892854239127       (3, 5)                   My Start
# 7892854239121      (8, 14)                    My data
# 7892854238833     (15, 21)               Another data
# 7892854239094       (1, 2)                       None
# 7892854239148       (6, 7)                       None
# 7892854238872     (22, 24)                       None
#
#                                                          RawData  \
# 7892854239037  TOTAL RUN TIME: 0 days 0 hours 0 minutes 26 se...
# 7892854239088                               ****ORCA TERMINAT...
# 7892854239181  -------------------------   ------------------...
# 7892854239127      My start of the message: message1\nmessage2\n
# 7892854239121  --------------------\nMy data\n---------------...
# 7892854238833                              ******************...
# 7892854239094                                                 \n
# 7892854239148                                                 \n
# 7892854238872                                               \n\n
#
#                            ExtractedData
# 7892854239037                 [Run Time]
# 7892854239088       [Termination status]
# 7892854239181                   [Energy]
# 7892854239127                 [raw data]
# 7892854239121  [My value, Another Value]
# 7892854238833                 [raw data]
# 7892854239094                       None
# 7892854239148                       None
# 7892854238872                       None

# %% [markdown]
# Now our data is ready to be extracted:

# %%
df = orca_file.get_data(element_type=BlockOrcaMyData)
display(df)
assert len(df) == 1, "More then 1 `BlockOrcaMyData` found"
data = df.iloc[0].ExtractedData
print(data)
print()
print(f"{data['My value'].magnitude = }")
print(f"{data['Another Value'] = }")
# Out:
#                 Type          Subtype  \
# 7892854239121  Block  BlockOrcaMyData
#
#                                                          Element CharPosition  \
# 7892854239121  <__main__.BlockOrcaMyData object at 0x72db2c5e...    (45, 116)
#
#               LinePosition ReadableName  \
# 7892854239121      (8, 14)      My data
#
#                                                          RawData  \
# 7892854239121  --------------------\nMy data\n---------------...
#
#                            ExtractedData
# 7892854239121  [My value, Another Value]
# OrcaData with items: `My value`, `Another Value`. Comment: Contains pint object of `My value`. The magnitude in eV can be extracted with property .magnitude
# `Another value` is 42.
#
# data['My value'].magnitude = 1.234
# data['Another Value'] = 42

# %% [markdown]
# Let's looks at the search algorithm structure
#
# `RegexSettings` is a tree/'directory' object that contains  `RegexSettings`s, `RegexBlueprint`s and `RegexRequest`s. `RegexBlueprint` is a 'generator' object for `RegexRequest`s of the same type. They have `.items` that contains `RegexRequest`s as it was previously shown.

# %%
rs = op.RegexSettings(op.DEFAULT_ORCA_REGEX_FILE)
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaTotalRunTime: RegexRequest(p_type=Block, p_subtype=BlockOrcaTotalRunTime, pattern=^([ \t]*TOTAL RUN TIME:\s..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockOrcaTerminatedNormally: RegexRequest(p_type=Block, p_subtype=BlockOrcaTerminatedNormally, pattern=^([ \t]*\*{4}ORCA TERMINA..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type=Block, p_subtype=BlockOrcaFinalSinglePointEnergy, pattern=^((-{20,}\s+-{15,}\n)[ \t..., flags=re.MULTILINE, comment=This pattern matches the ...)
#       BlockOrcaDipoleMoment: RegexRequest(p_type=Block, p_subtype=BlockOrcaDipoleMoment, pattern=^(([ \t]*-{10,}[ \t]*\n[ ..., flags=re.MULTILINE, comment=Equal signs around the IN...)
#       BlockOrcaInputFile: RegexRequest(p_type=Block, p_subtype=BlockOrcaInputFile, pattern=^((?:[ \t]*={10,}[ \t]*\n..., flags=re.MULTILINE, comment=Equal signs around the IN...)
#       BlockOrcaShark: RegexRequest(p_type=Block, p_subtype=BlockOrcaShark, pattern=^((?:[ \t]*-{50,}[ \t]*\n..., flags=re.MULTILINE, comment=Starts with line of  --- ...)
#       BlockOrcaWarnings: RegexRequest(p_type=Block, p_subtype=BlockOrcaWarnings, pattern=^((?:[ \t]*\={5,}[ \t]*\n..., flags=re.MULTILINE, comment=WARNINGS, should capture ...)
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*Rotational spectrum[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#       BlueprintBlockWithInlineHeader:
#         RegexBlueprint:
#           BlockOrcaOrbitalBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*Orbital basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAuxJBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*AuxJ basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockNote:
#         RegexBlueprint:
#           BlockOrcaAllRightsReserved: Pattern: ^((?:[ \t]*(([\-\*\#\=]){5,})[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(^[ \t]*\3[ \t]*All rights reserved[ \t]*\3[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(?:[ \t]*\2[ \t]*\n))
#       BlueprintBlockSCF:
#         RegexBlueprint:
#           BlockOrcaScf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaSoscf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-O-S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlockOrcaScfConverged: RegexRequest(p_type=Block, p_subtype=BlockOrcaScfConverged, pattern=^((?:[ \t]*\*{5,}[ \t]*\n..., flags=re.MULTILINE, comment=Note, but with CF CONVERG...)
#       BlockOrcaIcon: RegexRequest(p_type=Block, p_subtype=BlockOrcaIcon, pattern=^((?:^[ \t]*#,[ \t]*\n[ \..., flags=re.MULTILINE, comment=Unsafe as can ignore the ...)
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithHeader: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedWithHeader, pattern=(([ \t]*[\-\*\#\=]{5,}[ \..., flags=re.MULTILINE, comment=Special, from 1 to 3 non-...)
#   Spacer: RegexRequest(p_type=Spacer, p_subtype=Spacer, pattern=^(\s*\n), flags=re.MULTILINE, comment=Just some empty lines, ma...)

# %% [markdown]
# You can create the new instance of `RegexSettings`, `RegexBlueprint` or `RegexRequest` and add it with .add_item.
#
# `TypeKnownBlocks` is made for specific patterns for known blocks
#
# `TypeDefaultBlocks` is made for the general patters to find some specific kinds of blocks, data extraction is not expected from the blocks in this section
#
# `BlockOrcaUnknown` is the `RegexRequest` to collect everything that was not recognized before as a block and is not just a space
#
# `Spacer` collects the spaces left in the document

# %%
pattern = op.regex_request.RegexRequest(
    p_type="Block",
    p_subtype="BlockOrcaDemonstration",
    pattern="^(aaa)$",
    flags=["MULTILINE"],
    comment="Patterns should always start with ^, have at least 1 capturing group and end with $",
)
pattern
# Out:
# RegexRequest(p_type=Block, p_subtype=BlockOrcaDemonstration, pattern=^(aaa)$, flags=re.MULTILINE, comment=Patterns should always st...)

# %% [markdown]
# Patterns should always start with `^`, have at least 1 capturing group and end with `$`. This capturing group will capture the `raw_data`

# %%
rs.items["TypeKnownBlocks"].add_item(name="BlockOrcaDemonstration", item=pattern)

# %% [markdown]
# Pattern was successfully added:

# %%
print(rs)
# Out:
# RegexGroup:
#   TypeKnownBlocks:
#     RegexGroup:
#       BlockOrcaTotalRunTime: RegexRequest(p_type=Block, p_subtype=BlockOrcaTotalRunTime, pattern=^([ \t]*TOTAL RUN TIME:\s..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockOrcaTerminatedNormally: RegexRequest(p_type=Block, p_subtype=BlockOrcaTerminatedNormally, pattern=^([ \t]*\*{4}ORCA TERMINA..., flags=re.MULTILINE, comment=This pattern captures the...)
#       BlockOrcaFinalSinglePointEnergy: RegexRequest(p_type=Block, p_subtype=BlockOrcaFinalSinglePointEnergy, pattern=^((-{20,}\s+-{15,}\n)[ \t..., flags=re.MULTILINE, comment=This pattern matches the ...)
#       BlockOrcaDipoleMoment: RegexRequest(p_type=Block, p_subtype=BlockOrcaDipoleMoment, pattern=^(([ \t]*-{10,}[ \t]*\n[ ..., flags=re.MULTILINE, comment=Equal signs around the IN...)
#       BlockOrcaInputFile: RegexRequest(p_type=Block, p_subtype=BlockOrcaInputFile, pattern=^((?:[ \t]*={10,}[ \t]*\n..., flags=re.MULTILINE, comment=Equal signs around the IN...)
#       BlockOrcaShark: RegexRequest(p_type=Block, p_subtype=BlockOrcaShark, pattern=^((?:[ \t]*-{50,}[ \t]*\n..., flags=re.MULTILINE, comment=Starts with line of  --- ...)
#       BlockOrcaWarnings: RegexRequest(p_type=Block, p_subtype=BlockOrcaWarnings, pattern=^((?:[ \t]*\={5,}[ \t]*\n..., flags=re.MULTILINE, comment=WARNINGS, should capture ...)
#       BlueprintParagraphStartsWith:
#         RegexBlueprint:
#           BlockOrcaVersion: Pattern: ^([ \t]*Program Version.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaContributions: Pattern: ^([ \t]*With contributions from.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAcknowledgement: Pattern: ^([ \t]*We gratefully acknowledge.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibint2: Pattern: ^([ \t]*Your calculation uses the libint2.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaLibXc: Pattern: ^([ \t]*Your ORCA version has been built with support for libXC.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaUses: Pattern: ^([ \t]*This ORCA versions uses.*?\n(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockWithSingeLineHeader:
#         RegexBlueprint:
#           BlockOrcaRotationalSpectrum: Pattern: ^((?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:[ \t]*Rotational spectrum[ \t]*\n)(?:^[ \t]*[\-\*\#\=]{5,}.*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$).*\n)*)
#       BlueprintBlockWithInlineHeader:
#         RegexBlueprint:
#           BlockOrcaOrbitalBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*Orbital basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaAuxJBasis: Pattern: ^((?:^[ \t]*([\-\*\#\=]+)[ \t]*AuxJ basis set information[ \t]*\2[ \t]*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlueprintBlockNote:
#         RegexBlueprint:
#           BlockOrcaAllRightsReserved: Pattern: ^((?:[ \t]*(([\-\*\#\=]){5,})[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(^[ \t]*\3[ \t]*All rights reserved[ \t]*\3[ \t]*\n)(?:^[ \t]*\3(?!\3).*\3[ \t]*\n)*?(?:[ \t]*\2[ \t]*\n))
#       BlueprintBlockSCF:
#         RegexBlueprint:
#           BlockOrcaScf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#           BlockOrcaSoscf: Pattern: ^((?:(?:[ \t]*([\-\*\#\=]){5,})[ \t]*S-O-S-C-F[ \t]*\2{7,}\n)(?:(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n){1,2}(?:\2*\n)(?:^(?!^[ \t]*[\-\*\#\=]{5,}.*$|^[ \t]*$).*\n)*)
#       BlockOrcaScfConverged: RegexRequest(p_type=Block, p_subtype=BlockOrcaScfConverged, pattern=^((?:[ \t]*\*{5,}[ \t]*\n..., flags=re.MULTILINE, comment=Note, but with CF CONVERG...)
#       BlockOrcaIcon: RegexRequest(p_type=Block, p_subtype=BlockOrcaIcon, pattern=^((?:^[ \t]*#,[ \t]*\n[ \..., flags=re.MULTILINE, comment=Unsafe as can ignore the ...)
#       BlockOrcaDemonstration: RegexRequest(p_type=Block, p_subtype=BlockOrcaDemonstration, pattern=^(aaa)$, flags=re.MULTILINE, comment=Patterns should always st...)
#   TypeDefaultBlocks:
#     RegexGroup:
#       BlockOrcaUnrecognizedWithHeader: RegexRequest(p_type=Block, p_subtype=BlockOrcaUnrecognizedWithHeader, pattern=(([ \t]*[\-\*\#\=]{5,}[ \..., flags=re.MULTILINE, comment=Special, from 1 to 3 non-...)
#   Spacer: RegexRequest(p_type=Spacer, p_subtype=Spacer, pattern=^(\s*\n), flags=re.MULTILINE, comment=Just some empty lines, ma...)
